# %%
import ezdxf
import numpy

# Open the DWG file
doc = ezdxf.readfile("Drawing1.dxf")

# Access the modelspace
msp = doc.modelspace()

lines = msp.query('LINE[layer=="SOL-PV MODULES"]')
# Iterate over entities in the modelspace

print (doc)

#for entity in msp:
 #   print(entity.)
# Out:
# <ezdxf.document.Drawing object at 0x000002A60850FD40>

# %%
print('Helloworld!')
# Out:
# Helloworld!

# %%
# helper function
def print_entity(e):
    print("LINE on layer: %s\n" % e.dxf.layer)
    print("start point: %s\n" % e.dxf.start)
    print("end point: %s\n" % e.dxf.end)

# iterate over all entities in modelspace
msp = doc.modelspace()
for e in msp:
    if e.dxftype() == "LINE":
        print_entity(e)

# entity query for all LINE entities in modelspace
for e in msp.query("LINE"):
    print_entity(e)

# %%
import ezdxf

def read_lwpolylines_from_dxf():
    """
    Reads all LWPOLYLINE entities from a DXF file named 'Drawing1.dxf'
    located in 'C:\\Users\\Mariusr\\Documents\\programming_stuff'.
    
    :return: A list of dictionaries containing information about each LWPOLYLINE
    """
    file_path = "Drawing4.dxf"
    
    try:
        # Load the DXF document
        doc = ezdxf.readfile(file_path)
        # Access the modelspace where entities are typically stored
        msp = doc.modelspace()
        
        # Initialize a list to hold information about all LWPOLYLINEs
        lwpolyline_data = []
        
        # Iterate over all LWPOLYLINE entities in the modelspace
        for lwpolyline in msp.query("LWPOLYLINE"):
            # Extract vertex data as tuples of (x, y, start_width, end_width, bulge)
            points = [(float(x), float(y)) for x, y, _, _, _ in lwpolyline]
            
            # Store the extracted information
            data = {
                "points": points,  # List of vertex tuples
                "is_closed": lwpolyline.is_closed,  # Whether the polyline is closed
                "layer": lwpolyline.dxf.layer,  # Layer of the polyline
            }
            lwpolyline_data.append(data)
        
        return lwpolyline_data
    
    except IOError:
        print("Could not read the DXF file. Please check the file path.")
        return []
    except ezdxf.DXFStructureError:
        print("Invalid DXF file structure.")
        return []

# Call the function and print the extracted LWPOLYLINE information
lwpolylines = read_lwpolylines_from_dxf()

for idx, polyline in enumerate(lwpolylines, start=1):
    print(f"LWPOLYLINE {idx}:")
    print(polyline)
# Out:
# LWPOLYLINE 1:
# {'points': [(132392.5908664562, 265521.2740660743), (130062.7881618735, 265521.2740660743), (130062.7881618735, 264387.2740660743), (132392.5908664562, 264387.2740660743)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 2:
# {'points': [(132402.577161804, 265521.2740660743), (134732.3798663862, 265521.2740660743), (134732.379866386, 264387.2740660743), (132402.5771618036, 264387.2740660743)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3:
# {'points': [(137461.6343848698, 265521.2740660743), (135131.8316802878, 265521.2740660743), (135131.8316802875, 264387.2740660743), (137461.6343848693, 264387.2740660743)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 4:
# {'points': [(137471.6206802183, 265521.2740660743), (139801.4233848007, 265521.2740660743), (139801.4233848007, 264387.2740660743), (137471.620680218, 264387.2740660743)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 5:
# {'points': [(142930.1297171863, 265521.2740660743), (140600.3270126045, 265521.2740660743), (140600.327012604, 264387.2740660743), (142930.129717186, 264387.2740660743)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 6:
# {'points': [(142940.1160125343, 265521.2740660743), (145269.9187171165, 265521.2740660743), (145269.9187171165, 264387.2740660743), (142940.1160125343, 264387.2740660743)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE
], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3344:
# {'points': [(184531.6008910015, 35192.15436406016), (183629.0219697561, 35878.67260192662), (182238.0921360808, 34049.99001265063), (183140.6710573262, 33363.47177478416)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3345:
# {'points': [(182203.0591299277, 34045.22677007179), (181300.4802086823, 34731.74500793825), (179909.550375007, 32903.06241866249), (180812.1292962524, 32216.5441807958)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3346:
# {'points': [(183125.5361755392, 33343.57365041833), (182222.9572542938, 34030.09188828479), (180832.0274206185, 32201.4092990088), (181734.6063418639, 31514.89106114233)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3347:
# {'points': [(180796.9944144654, 32196.64605642973), (179894.4154932196, 32883.16429429642), (178503.4856595443, 31054.48170502043), (179406.0645807902, 30367.96346715397)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3348:
# {'points': [(181719.4714600769, 31494.99293677627), (180816.8925388315, 32181.51117464273), (179425.9627051562, 30352.82858536673), (180328.5416264017, 29666.31034750027)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3349:
# {'points': [(180313.4067446142, 29646.4122231342), (179410.8278233688, 30332.93046100067), (178019.897989694, 28504.24787172467), (178922.4769109394, 27817.72963385821)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3350:
# {'points': [(177984.8649835404, 28499.48462914584), (177082.286062295, 29186.0028670123), (175691.3562286198, 27357.3202777363), (176593.9351498652, 26670.80203987008)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3351:
# {'points': [(178907.3420291524, 27797.83150949237), (178004.7631079065, 28484.34974735884), (176613.8332742312, 26655.66715808284), (177516.4121954771, 25969.14892021638)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3352:
# {'points': [(179390.9296990032, 30348.06534278767), (178488.3507777573, 31034.58358065413), (177097.4209440825, 29205.90099137813), (177999.9998653279, 28519.38275351167)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3353:
# {'points': [(155323.3261735346, 79470.03101858626), (154244.8280840557, 79820.45629020735), (153534.8440837962, 77635.35022095033), (154613.3421732745, 77284.92494932924)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3354:
# {'points': [(203690.2496259426, 34487.38395268355), (202898.760078839, 35299.48018886872), (201253.4011933482, 33695.87177268254), (202044.8907404513, 32883.77553649737)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}
# LWPOLYLINE 3355:
# {'points': [(207780.327701189, 33618.44265587303), (206988.8381540859, 34430.53889205844), (205343.4792685946, 32826.93047587179), (206134.9688156978, 32014.83423968662)], 'is_closed': True, 'layer': 'SOL-PV MODULES'}

# %%
def validate_rectangle(polyline):
    """
    Validates if a polyline forms a rectangle by checking dot products of consecutive vectors.
    
    :param polyline: Dictionary containing points of the polyline.
    :return: True if it is a rectangle, False otherwise.
    """
    points = polyline["points"]  # List of (x, y) tuples

    # Ensure the polyline has exactly 4 vertices and is closed
    if len(points) != 4 or not polyline["is_closed"]:
        return False

    # Calculate vectors for consecutive points (ensure loop closure with points[0])
    vectors = [(points[i][0] - points[i - 1][0], points[i][1] - points[i - 1][1]) for i in range(4)]

    # Check dot products of consecutive vectors
    for i in range(4):
        v1 = vectors[i]
        v2 = vectors[(i + 1) % 4]  # Wrap around to check last with first
        dot_product = v1[0] * v2[0] + v1[1] * v2[1]
        
        # If the dot product is not zero, it's not a rectangle
        if dot_product != 0:
            return False

    return True

# Iterate through all LWPOLYLINEs and validate
for idx, polyline in enumerate(lwpolylines, start=1):
    is_rectangle = validate_rectangle(polyline)
    print(f"LWPOLYLINE {idx}: {'Is a rectangle' if is_rectangle else 'Not a rectangle'}")
# Out:
# LWPOLYLINE 1: Is a rectangle
# LWPOLYLINE 2: Not a rectangle
# LWPOLYLINE 3: Not a rectangle
# LWPOLYLINE 4: Not a rectangle
# LWPOLYLINE 5: Not a rectangle
# LWPOLYLINE 6: Is a rectangle
# LWPOLYLINE 7: Not a rectangle
# LWPOLYLINE 8: Not a rectangle
# LWPOLYLINE 9: Not a rectangle
# LWPOLYLINE 10: Not a rectangle
# LWPOLYLINE 11: Is a rectangle
# LWPOLYLINE 12: Is a rectangle
# LWPOLYLINE 13: Is a rectangle
# LWPOLYLINE 14: Is a rectangle
# LWPOLYLINE 15: Not a rectangle
# LWPOLYLINE 16: Not a rectangle
# LWPOLYLINE 17: Is a rectangle
# LWPOLYLINE 18: Not a rectangle
# LWPOLYLINE 19: Is a rectangle
# LWPOLYLINE 20: Not a rectangle
# LWPOLYLINE 21: Not a rectangle
# LWPOLYLINE 22: Not a rectangle
# LWPOLYLINE 23: Not a rectangle
# LWPOLYLINE 24: Is a rectangle
# LWPOLYLINE 25: Is a rectangle
# LWPOLYLINE 26: Not a rectangle
# LWPOLYLINE 27: Not a rectangle
# LWPOLYLINE 28: Not a rectangle
# LWPOLYLINE 29: Not a rectangle
# LWPOLYLINE 30: Is a rectangle
# LWPOLYLINE 31: Is a rectangle
# LWPOLYLINE 32: Not a rectangle
# LWPOLYLINE 33: Not a rectangle
# LWPOLYLINE 34: Not a rectangle
# LWPOLYLINE 35: Not a rectangle
# LWPOLYLINE 36: Is a rectangle
# LWPOLYLINE 37: Is a rectangle
# LWPOLYLINE 38: Not a rectangle
# LWPOLYLINE 39: Not a rectangle
# LWPOLYLINE 40: Not a rectangle
# LWPOLYLINE 41: Not a rectangle
# LWPOLYLINE 42: Is a rectangle
# LWPOLYLINE 43: Is a rectangle
# LWPOLYLINE 44: Not a rectangle
# LWPOLYLINE 45: Not a rectangle
# LWPOLYLINE 46: Not a rectangle
# LWPOLYLINE 47: Not a rectangle
# LWPOLYLINE 48: Is a rectangle
# LWPOLYLINE 49: Is a rectangle
# LWPOLYLINE 50: Not a rectangle
# LWPOLYLINE 51: Not a rectangle
# LWPOLYLINE 52: Not a rectangle
# LWPOLYLINE 53: Not a rectangle
# LWPOLYLINE 54: Is a rectangle
# LWPOLYLINE 55: Is a rectangle
# LWPOLYLINE 56: Not a rectangle
# LWPOLYLINE 57: Not a rectangle
# LWPOLYLINE 58: Not a rectangle
# LWPOLYLINE 59: Not a rectangle
# LWPOLYLINE 60: Is a rectangle
# LWPOLYLINE 61: Is a rectangle
# LWPOLYLINE 62: Not a rectangle
# LWPOLYLINE 63: Not a rectangle
# LWPOLYLINE 64: Not a rectangle
# LWPOLYLINE 65: Not a rectangle
# LWPOLYLINE 66: Is a rectangle
# LWPOLYLINE 67: Is a rectangle
# LWPOLYLINE 68: Not a rectangle
# LWPOLYLINE 69: Not a rectangle
# LWPOLYLINE 70: Not a rectangle
# LWPOLYLINE 71: Not a rectangle
# LWPOLYLINE 72: Is a rectangle
# LWPOLYLINE 73: Is a rectangle
# LWPOLYLINE 74: Not a rectangle
# LWPOLYLINE 75: Not a rectangle
# LWPOLYLINE 76: Not a rectangle
# LWPOLYLINE 77: Not a rectangle
# LWPOLYLINE 78: Is a rectangle
# LWPOLYLINE 79: Is a rectangle
# LWPOLYLINE 80: Not a rectangle
# LWPOLYLINE 81: Not a rectangle
# LWPOLYLINE 82: Not a rectangle
# LWPOLYLINE 83: Not a rectangle
# LWPOLYLINE 84: Is a rectangle
# LWPOLYLINE 85: Is a rectangle
# LWPOLYLINE 86: Not a rectangle
# LWPOLYLINE 87: Not a rectangle
# LWPOLYLINE 88: Not a rectangle
# LWPOLYLINE 89: Not a rectangle
# LWPOLYLINE 90: Is a rectangle
# LWPOLYLINE 91: Is a rectangle
# LWPOLYLINE 92: Not a rectangle
# LWPOLYLINE 93: Not a rectangle
# LWPOLYLINE 94: Not a rectangle
# LWPOLYLINE 95: Not a rectangle
# LWPOLYLINE 96: Is a rectangle
# LWPOLYLINE 97: Is a rectangle
# LWPOLYLINE 98: Not a rectangle
# LWPOLYLINE 99: Not a rectangle
# LWPOLYLINE 100: Not a rectangle
# LWPOLYLINE 101: Not a rectangle
# LWPOLYLINE 102: Is a rectangle
# LWPOLYLINE 103: Is a rectangle
# LWPOLYLINE 104: Not a rectangle
# LWPOLYLINE 105: Not a rectangle
# LWPOLYLINE 106: Not a rectangle
# LWPOLYLINE 107: Not a rectangle
# LWPOLYLINE 108: Is a rectangle
# LWPOLYLINE 109: Is a rectangle
# LWPOLYLINE 110: Not a rectangle
# LWPOLYLINE 111: Not a rectangle
# LWPOLYLINE 112: Not a rectangle
# LWPOLYLINE 113: Not a rectangle
# LWPOLYLINE 114: Is a rectangle
# LWPOLYLINE 115: Is a rectangle
# LWPOLYLINE 116: Not a rectangle
# LWPOLYLINE 117: Not a rectangle
# LWPOLYLINE 118: Not a rectangle
# LWPOLYLINE 119: Not a rectangle
# LWPOLYLINE 120: Is a rectangle
# LWPOLYLINE 121: Is a rectangle
# LWPOLYLINE 122: Not a rectangle
# LWPOLYLINE 123: Not a rectangle
# LWPOLYLINE 124: Not a rectangle
# LWPOLYLINE 125: Not a rectangle
# LWPOLYLINE 126: Is a rectangle
# LWPOLYLINE 127: Is a rectangle
# LWPOLYLINE 128: Not a rectangle
# LWPOLYLINE 129: Not a rectangle
# LWPOLYLINE 130: Not a rectangle
# LWPOLYLINE 131: Not a rectangle
# LWPOLYLINE 132: Is a rectangle
# LWPOLYLINE 133: Not a rectangle
# LWPOLYLINE 134: Not a rectangle
# LWPOLYLINE 135: Not a rectangle
# LWPOLYLINE 136: Not a rectangle
# LWPOLYLINE 137: Is a rectangle
# LWPOLYLINE 138: Is a rectangle
# LWPOLYLINE 139: Is a rectangle
# LWPOLYLINE 140: Not a rectangle
# LWPOLYLINE 141: Not a rectangle
# LWPOLYLINE 142: Not a rectangle
# LWPOLYLINE 143: Not a rectangle
# LWPOLYLINE 144: Is a rectangle
# LWPOLYLINE 145: Is a rectangle
# LWPOLYLINE 146: Not a rectangle
# LWPOLYLINE 147: Not a rectangle
# LWPOLYLINE 148: Not a rectangle
# LWPOLYLINE 149: Not a rectangle
# LWPOLYLINE 150: Is a rectangle
# LWPOLYLINE 151: Is a rectangle
# LWPOLYLINE 152: Not a rectangle
# LWPOLYLINE 153: Not a rectangle
# LWPOLYLINE 154: Not a rectangle
# LWPOLYLINE 155: Not a rectangle
# LWPOLYLINE 156: Is a rectangle
# LWPOLYLINE 157: Is a rectangle
# LWPOLYLINE 158: Not a rectangle
# LWPOLYLINE 159: Not a rectangle
# LWPOLYLINE 160: Not a rectangle
# LWPOLYLINE 161: Not a rectangle
# LWPOLYLINE 162: Is a rectangle
# LWPOLYLINE 163: Is a rectangle
# LWPOLYLINE 164: Not a rectangle
# LWPOLYLINE 165: Not a rectangle
# LWPOLYLINE 166: Not a rectangle
# LWPOLYLINE 167: Not a rectangle
# LWPOLYLINE 168: Is a rectangle
# LWPOLYLINE 169: Is a rectangle
# LWPOLYLINE 170: Not a rectangle
# LWPOLYLINE 171: Not a rectangle
# LWPOLYLINE 172: Not a rectangle
# LWPOLYLINE 173: Not a rectangle
# LWPOLYLINE 174: Is a rectangle
# LWPOLYLINE 175: Is a rectangle
# LWPOLYLINE 176: Not a rectangle
# LWPOLYLINE 177: Not a rectangle
# LWPOLYLINE 178: Not a rectangle
# LWPOLYLINE 179: Not a rectangle
# LWPOLYLINE 180: Is a rectangle
# LWPOLYLINE 181: Is a rectangle
# LWPOLYLINE 182: Not a rectangle
# LWPOLYLINE 183: Not a rectangle
# LWPOLYLINE 184: Not a rectangle
# LWPOLYLINE 185: Not a rectangle
# LWPOLYLINE 186: Is a rectangle
# LWPOLYLINE 187: Is a rectangle
# LWPOLYLINE 188: Not a rectangle
# LWPOLYLINE 189: Not a rectangle
# LWPOLYLINE 190: Not a rectangle
# LWPOLYLINE 191: Not a rectangle
# LWPOLYLINE 192: Is a rectangle
# LWPOLYLINE 193: Is a rectangle
# LWPOLYLINE 194: Not a rectangle
# LWPOLYLINE 195: Not a rectangle
# LWPOLYLINE 196: Not a rectangle
# LWPOLYLINE 197: Not a rectangle
# LWPOLYLINE 198: Is a rectangle
# LWPOLYLINE 199: Is a rectangle
# LWPOLYLINE 200: Not a rectangle
# LWPOLYLINE 201: Not a rectangle
# LWPOLYLINE 202: Not a rectangle
# LWPOLYLINE 203: Not a rectangle
# LWPOLYLINE 204: Is a rectangle
# LWPOLYLINE 205: Is a rectangle
# LWPOLYLINE 206: Not a rectangle
# LWPOLYLINE 207: Not a rectangle
# LWPOLYLINE 208: Not a rectangle
# LWPOLYLINE 209: Not a rectangle
# LWPOLYLINE 210: Is a rectangle
# LWPOLYLINE 211: Is a rectangle
# LWPOLYLINE 212: Not a rectangle
# LWPOLYLINE 213: Not a rectangle
# LWPOLYLINE 214: Not a rectangle
# LWPOLYLINE 215: Not a rectangle
# LWPOLYLINE 216: Is a rectangle
# LWPOLYLINE 217: Is a rectangle
# LWPOLYLINE 218: Not a rectangle
# LWPOLYLINE 219: Not a rectangle
# LWPOLYLINE 220: Not a rectangle
# LWPOLYLINE 221: Not a rectangle
# LWPOLYLINE 222: Is a rectangle
# LWPOLYLINE 223: Is a rectangle
# LWPOLYLINE 224: Not a rectangle
# LWPOLYLINE 225: Not a rectangle
# LWPOLYLINE 226: Not a rectangle
# LWPOLYLINE 227: Not a rectangle
# LWPOLYLINE 228: Is a rectangle
# LWPOLYLINE 229: Is a rectangle
# LWPOLYLINE 230: Not a rectangle
# LWPOLYLINE 231: Not a rectangle
# LWPOLYLINE 232: Not a rectangle
# LWPOLYLINE 233: Not a rectangle
# LWPOLYLINE 234: Is a rectangle
# LWPOLYLINE 235: Is a rectangle
# LWPOLYLINE 236: Not a rectangle
# LWPOLYLINE 237: Not a rectangle
# LWPOLYLINE 238: Not a rectangle
# LWPOLYLINE 239: Not a rectangle
# LWPOLYLINE 240: Is a rectangle
# LWPOLYLINE 241: Is a rectangle
# LWPOLYLINE 242: Is a rectangle
# LWPOLYLINE 243: Not a rectangle
# LWPOLYLINE 244: Not a rectangle
# LWPOLYLINE 245: Is a rectangle
# LWPOLYLINE 246: Not a rectangle
# LWPOLYLINE 247: Is a rectangle
# LWPOLYLINE 248: Not a rectangle
# LWPOLYLINE 249: Not a rectangle
# LWPOLYLINE 250: Not a rectangle
# LWPOLYLINE 251: Not a rectangle
# LWPOLYLINE 252: Is a rectangle
# LWPOLYLINE 253: Not a rectangle
# LWPOLYLINE 254: Not a rectangle
# LWPOLYLINE 255: Not a rectangle
# LWPOLYLINE 256: Not a rectangle
# LWPOLYLINE 257: Is a rectangle
# LWPOLYLINE 258: Is a rectangle
# LWPOLYLINE 259: Is a rectangle
# LWPOLYLINE 260: Not a rectangle
# LWPOLYLINE 261: Not a rectangle
# LWPOLYLINE 262: Not a rectangle
# LWPOLYLINE 263: Not a rectangle
# LWPOLYLINE 264: Is a rectangle
# LWPOLYLINE 265: Is a rectangle
# LWPOLYLINE 266: Not a rectangle
# LWPOLYLINE 267: Not a rectangle
# LWPOLYLINE 268: Not a rectangle
# LWPOLYLINE 269: Not a rectangle
# LWPOLYLINE 270: Is a rectangle
# LWPOLYLINE 271: Is a rectangle
# LWPOLYLINE 272: Not a rectangle
# LWPOLYLINE 273: Not a rectangle
# LWPOLYLINE 274: Not a rectangle
# LWPOLYLINE 275: Not a rectangle
# LWPOLYLINE 276: Is a rectangle
# LWPOLYLINE 277: Is a rectangle
# LWPOLYLINE 278: Not a rectangle
# LWPOLYLINE 279: Not a rectangle
# LWPOLYLINE 280: Not a rectangle
# LWPOLYLINE 281: Not a rectangle
# LWPOLYLINE 282: Is a rectangle
# LWPOLYLINE 283: Is a rectangle
# LWPOLYLINE 284: Not a rectangle
# LWPOLYLINE 285: Not a rectangle
# LWPOLYLINE 286: Not a rectangle
# LWPOLYLINE 287: Not a rectangle
# LWPOLYLINE 288: Is a rectangle
# LWPOLYLINE 289: Is a rectangle
# LWPOLYLINE 290: Not a rectangle
# LWPOLYLINE 291: Not a rectangle
# LWPOLYLINE 292: Not a rectangle
# LWPOLYLINE 293: Not a rectangle
# LWPOLYLINE 294: Is a rectangle
# LWPOLYLINE 295: Is a rectangle
# LWPOLYLINE 296: Not a rectangle
# LWPOLYLINE 297: Not a rectangle
# LWPOLYLINE 298: Not a rectangle
# LWPOLYLINE 299: Not a rectangle
# LWPOLYLINE 300: Is a rectangle
# LWPOLYLINE 301: Is a rectangle
# LWPOLYLINE 302: Not a rectangle
# LWPOLYLINE 303: Not a rectangle
# LWPOLYLINE 304: Not a rectangle
# LWPOLYLINE 305: Not a rectangle
# LWPOLYLINE 306: Is a rectangle
# LWPOLYLINE 307: Is a rectangle
# LWPOLYLINE 308: Not a rectangle
# LWPOLYLINE 309: Not a rectangle
# LWPOLYLINE 310: Not a rectangle
# LWPOLYLINE 311: Not a rectangle
# LWPOLYLINE 312: Is a rectangle
# LWPOLYLINE 313: Is a rectangle
# LWPOLYLINE 314: Not a rectangle
# LWPOLYLINE 315: Not a rectangle
# LWPOLYLINE 316: Not a rectangle
# LWPOLYLINE 317: Not a rectangle
# LWPOLYLINE 318: Is a rectangle
# LWPOLYLINE 319: Is a rectangle
# LWPOLYLINE 320: Not a rectangle
# LWPOLYLINE 321: Not a rectangle
# LWPOLYLINE 322: Not a rectangle
# LWPOLYLINE 323: Not a rectangle
# LWPOLYLINE 324: Is a rectangle
# LWPOLYLINE 325: Is a rectangle
# LWPOLYLINE 326: Not a rectangle
# LWPOLYLINE 327: Not a rectangle
# LWPOLYLINE 328: Not a rectangle
# LWPOLYLINE 329: Not a rectangle
# LWPOLYLINE 330: Is a rectangle
# LWPOLYLINE 331: Is a rectangle
# LWPOLYLINE 332: Not a rectangle
# LWPOLYLINE 333: Not a rectangle
# LWPOLYLINE 334: Not a rectangle
# LWPOLYLINE 335: Not a rectangle
# LWPOLYLINE 336: Is a rectangle
# LWPOLYLINE 337: Is a rectangle
# LWPOLYLINE 338: Not a rectangle
# LWPOLYLINE 339: Not a rectangle
# LWPOLYLINE 340: Not a rectangle
# LWPOLYLINE 341: Not a rectangle
# LWPOLYLINE 342: Is a rectangle
# LWPOLYLINE 343: Is a rectangle
# LWPOLYLINE 344: Not a rectangle
# LWPOLYLINE 345: Not a rectangle
# LWPOLYLINE 346: Not a rectangle
# LWPOLYLINE 347: Not a rectangle
# LWPOLYLINE 348: Is a rectangle
# LWPOLYLINE 349: Is a rectangle
# LWPOLYLINE 350: Not a rectangle
# LWPOLYLINE 351: Not a rectangle
# LWPOLYLINE 352: Not a rectangle
# LWPOLYLINE 353: Not a rectangle
# LWPOLYLINE 354: Is a rectangle
# LWPOLYLINE 355: Is a rectangle
# LWPOLYLINE 356: Not a rectangle
# LWPOLYLINE 357: Not a rectangle
# LWPOLYLINE 358: Not a rectangle
# LWPOLYLINE 359: Not a rectangle
# LWPOLYLINE 360: Is a rectangle
# LWPOLYLINE 361: Is a rectangle
# LWPOLYLINE 362: Is a rectangle
# LWPOLYLINE 363: Not a rectangle
# LWPOLYLINE 364: Not a rectangle
# LWPOLYLINE 365: Is a rectangle
# LWPOLYLINE 366: Not a rectangle
# LWPOLYLINE 367: Is a rectangle
# LWPOLYLINE 368: Not a rectangle
# LWPOLYLINE 369: Not a rectangle
# LWPOLYLINE 370: Not a rectangle
# LWPOLYLINE 371: Not a rectangle
# LWPOLYLINE 372: Is a rectangle
# LWPOLYLINE 373: Not a rectangle
# LWPOLYLINE 374: Not a rectangle
# LWPOLYLINE 375: Not a rectangle
# LWPOLYLINE 376: Not a rectangle
# LWPOLYLINE 377: Is a rectangle
# LWPOLYLINE 378: Is a rectangle
# LWPOLYLINE 379: Is a rectangle
# LWPOLYLINE 380: Not a rectangle
# LWPOLYLINE 381: Not a rectangle
# LWPOLYLINE 382: Not a rectangle
# LWPOLYLINE 383: Not a rectangle
# LWPOLYLINE 384: Is a rectangle
# LWPOLYLINE 385: Is a rectangle
# LWPOLYLINE 386: Not a rectangle
# LWPOLYLINE 387: Not a rectangle
# LWPOLYLINE 388: Not a rectangle
# LWPOLYLINE 389: Not a rectangle
# LWPOLYLINE 390: Is a rectangle
# LWPOLYLINE 391: Is a rectangle
# LWPOLYLINE 392: Not a rectangle
# LWPOLYLINE 393: Not a rectangle
# LWPOLYLINE 394: Not a rectangle
# LWPOLYLINE 395: Not a rectangle
# LWPOLYLINE 396: Is a rectangle
# LWPOLYLINE 397: Is a rectangle
# LWPOLYLINE 398: Not a rectangle
# LWPOLYLINE 399: Not a rectangle
# LWPOLYLINE 400: Not a rectangle
# LWPOLYLINE 401: Not a rectangle
# LWPOLYLINE 402: Is a rectangle
# LWPOLYLINE 403: Is a rectangle
# LWPOLYLINE 404: Not a rectangle
# LWPOLYLINE 405: Not a rectangle
# LWPOLYLINE 406: Not a rectangle
# LWPOLYLINE 407: Not a rectangle
# LWPOLYLINE 408: Is a rectangle
# LWPOLYLINE 409: Is a rectangle
# LWPOLYLINE 410: Not a rectangle
# LWPOLYLINE 411: Not a rectangle
# LWPOLYLINE 412: Not a rectangle
# LWPOLYLINE 413: Not a rectangle
# LWPOLYLINE 414: Is a rectangle
# LWPOLYLINE 415: Is a rectangle
# LWPOLYLINE 416: Not a rectangle
# LWPOLYLINE 417: Not a rectangle
# LWPOLYLINE 418: Not a rectangle
# LWPOLYLINE 419: Not a rectangle
# LWPOLYLINE 420: Is a rectangle
# LWPOLYLINE 421: Is a rectangle
# LWPOLYLINE 422: Not a rectangle
# LWPOLYLINE 423: Not a rectangle
# LWPOLYLINE 424: Not a rectangle
# LWPOLYLINE 425: Not a rectangle
# LWPOLYLINE 426: Is a rectangle
# LWPOLYLINE 427: Is a rectangle
# LWPOLYLINE 428: Not a rectangle
# LWPOLYLINE 429: Not a rectangle
# LWPOLYLINE 430: Not a rectangle
# LWPOLYLINE 431: Not a rectangle
# LWPOLYLINE 432: Is a rectangle
# LWPOLYLINE 433: Is a rectangle
# LWPOLYLINE 434: Not a rectangle
# LWPOLYLINE 435: Not a rectangle
# LWPOLYLINE 436: Not a rectangle
# LWPOLYLINE 437: Not a rectangle
# LWPOLYLINE 438: Is a rectangle
# LWPOLYLINE 439: Is a rectangle
# LWPOLYLINE 440: Not a rectangle
# LWPOLYLINE 441: Not a rectangle
# LWPOLYLINE 442: Not a rectangle
# LWPOLYLINE 443: Not a rectangle
# LWPOLYLINE 444: Is a rectangle
# LWPOLYLINE 445: Is a rectangle
# LWPOLYLINE 446: Not a rectangle
# LWPOLYLINE 447: Not a rectangle
# LWPOLYLINE 448: Not a rectangle
# LWPOLYLINE 449: Not a rectangle
# LWPOLYLINE 450: Is a rectangle
# LWPOLYLINE 451: Is a rectangle
# LWPOLYLINE 452: Not a rectangle
# LWPOLYLINE 453: Not a rectangle
# LWPOLYLINE 454: Not a rectangle
# LWPOLYLINE 455: Not a rectangle
# LWPOLYLINE 456: Is a rectangle
# LWPOLYLINE 457: Is a rectangle
# LWPOLYLINE 458: Not a rectangle
# LWPOLYLINE 459: Not a rectangle
# LWPOLYLINE 460: Not a rectangle
# LWPOLYLINE 461: Not a rectangle
# LWPOLYLINE 462: Is a rectangle
# LWPOLYLINE 463: Is a rectangle
# LWPOLYLINE 464: Not a rectangle
# LWPOLYLINE 465: Not a rectangle
# LWPOLYLINE 466: Not a rectangle
# LWPOLYLINE 467: Not a rectangle
# LWPOLYLINE 468: Is a rectangle
# LWPOLYLINE 469: Is a rectangle
# LWPOLYLINE 470: Not a rectangle
# LWPOLYLINE 471: Not a rectangle
# LWPOLYLINE 472: Not a rectangle
# LWPOLYLINE 473: Not a rectangle
# LWPOLYLINE 474: Is a rectangle
# LWPOLYLINE 475: Is a rectangle
# LWPOLYLINE 476: Not a rectangle
# LWPOLYLINE 477: Not a rectangle
# LWPOLYLINE 478: Not a rectangle
# LWPOLYLINE 479: Not a rectangle
# LWPOLYLINE 480: Is a rectangle
# LWPOLYLINE 481: Is a rectangle
# LWPOLYLINE 482: Is a rectangle
# LWPOLYLINE 483: Not a rectangle
# LWPOLYLINE 484: Not a rectangle
# LWPOLYLINE 485: Is a rectangle
# LWPOLYLINE 486: Not a rectangle
# LWPOLYLINE 487: Is a rectangle
# LWPOLYLINE 488: Not a rectangle
# LWPOLYLINE 489: Not a rectangle
# LWPOLYLINE 490: Not a rectangle
# LWPOLYLINE 491: Not a rectangle
# LWPOLYLINE 492: Is a rectangle
# LWPOLYLINE 493: Not a rectangle
# LWPOLYLINE 494: Not a rectangle
# LWPOLYLINE 495: Not a rectangle
# LWPOLYLINE 496: Not a rectangle
# LWPOLYLINE 497: Is a rectangle
# LWPOLYLINE 498: Is a rectangle
# LWPOLYLINE 499: Is a rectangle
# LWPOLYLINE 500: Not a rectangle
# LWPOLYLINE 501: Not a rectangle
# LWPOLYLINE 502: Not a rectangle
# LWPOLYLINE 503: Not a rectangle
# LWPOLYLINE 504: Is a rectangle
# LWPOLYLINE 505: Is a rectangle
# LWPOLYLINE 506: Not a rectangle
# LWPOLYLINE 507: Not a rectangle
# LWPOLYLINE 508: Not a rectangle
# LWPOLYLINE 509: Not a rectangle
# LWPOLYLINE 510: Is a rectangle
# LWPOLYLINE 511: Is a rectangle
# LWPOLYLINE 512: Not a rectangle
# LWPOLYLINE 513: Not a rectangle
# LWPOLYLINE 514: Not a rectangle
# LWPOLYLINE 515: Not a rectangle
# LWPOLYLINE 516: Is a rectangle
# LWPOLYLINE 517: Is a rectangle
# LWPOLYLINE 518: Not a rectangle
# LWPOLYLINE 519: Not a rectangle
# LWPOLYLINE 520: Not a rectangle
# LWPOLYLINE 521: Not a rectangle
# LWPOLYLINE 522: Is a rectangle
# LWPOLYLINE 523: Is a rectangle
# LWPOLYLINE 524: Not a rectangle
# LWPOLYLINE 525: Not a rectangle
# LWPOLYLINE 526: Not a rectangle
# LWPOLYLINE 527: Not a rectangle
# LWPOLYLINE 528: Is a rectangle
# LWPOLYLINE 529: Is a rectangle
# LWPOLYLINE 530: Not a rectangle
# LWPOLYLINE 531: Not a rectangle
# LWPOLYLINE 532: Not a rectangle
# LWPOLYLINE 533: Not a rectangle
# LWPOLYLINE 534: Is a rectangle
# LWPOLYLINE 535: Is a rectangle
# LWPOLYLINE 536: Not a rectangle
# LWPOLYLINE 537: Not a rectangle
# LWPOLYLINE 538: Not a rectangle
# LWPOLYLINE 539: Not a rectangle
# LWPOLYLINE 540: Is a rectangle
# LWPOLYLINE 541: Is a rectangle
# LWPOLYLINE 542: Not a rectangle
# LWPOLYLINE 543: Not a rectangle
# LWPOLYLINE 544: Not a rectangle
# LWPOLYLINE 545: Not a rectangle
# LWPOLYLINE 546: Is a rectangle
# LWPOLYLINE 547: Is a rectangle
# LWPOLYLINE 548: Not a rectangle
# LWPOLYLINE 549: Not a rectangle
# LWPOLYLINE 550: Not a rectangle
# LWPOLYLINE 551: Not a rectangle
# LWPOLYLINE 552: Is a rectangle
# LWPOLYLINE 553: Is a rectangle
# LWPOLYLINE 554: Not a rectangle
# LWPOLYLINE 555: Not a rectangle
# LWPOLYLINE 556: Not a rectangle
# LWPOLYLINE 557: Not a rectangle
# LWPOLYLINE 558: Is a rectangle
# LWPOLYLINE 559: Is a rectangle
# LWPOLYLINE 560: Not a rectangle
# LWPOLYLINE 561: Not a rectangle
# LWPOLYLINE 562: Not a rectangle
# LWPOLYLINE 563: Not a rectangle
# LWPOLYLINE 564: Is a rectangle
# LWPOLYLINE 565: Is a rectangle
# LWPOLYLINE 566: Not a rectangle
# LWPOLYLINE 567: Not a rectangle
# LWPOLYLINE 568: Not a rectangle
# LWPOLYLINE 569: Not a rectangle
# LWPOLYLINE 570: Is a rectangle
# LWPOLYLINE 571: Is a rectangle
# LWPOLYLINE 572: Not a rectangle
# LWPOLYLINE 573: Not a rectangle
# LWPOLYLINE 574: Not a rectangle
# LWPOLYLINE 575: Not a rectangle
# LWPOLYLINE 576: Is a rectangle
# LWPOLYLINE 577: Is a rectangle
# LWPOLYLINE 578: Not a rectangle
# LWPOLYLINE 579: Not a rectangle
# LWPOLYLINE 580: Not a rectangle
# LWPOLYLINE 581: Not a rectangle
# LWPOLYLINE 582: Is a rectangle
# LWPOLYLINE 583: Is a rectangle
# LWPOLYLINE 584: Not a rectangle
# LWPOLYLINE 585: Not a rectangle
# LWPOLYLINE 586: Not a rectangle
# LWPOLYLINE 587: Not a rectangle
# LWPOLYLINE 588: Is a rectangle
# LWPOLYLINE 589: Is a rectangle
# LWPOLYLINE 590: Not a rectangle
# LWPOLYLINE 591: Not a rectangle
# LWPOLYLINE 592: Not a rectangle
# LWPOLYLINE 593: Not a rectangle
# LWPOLYLINE 594: Is a rectangle
# LWPOLYLINE 595: Is a rectangle
# LWPOLYLINE 596: Not a rectangle
# LWPOLYLINE 597: Not a rectangle
# LWPOLYLINE 598: Not a rectangle
# LWPOLYLINE 599: Not a rectangle
# LWPOLYLINE 600: Is a rectangle
# LWPOLYLINE 601: Is a rectangle
# LWPOLYLINE 602: Is a rectangle
# LWPOLYLINE 603: Not a rectangle
# LWPOLYLINE 604: Not a rectangle
# LWPOLYLINE 605: Is a rectangle
# LWPOLYLINE 606: Not a rectangle
# LWPOLYLINE 607: Is a rectangle
# LWPOLYLINE 608: Not a rectangle
# LWPOLYLINE 609: Not a rectangle
# LWPOLYLINE 610: Not a rectangle
# LWPOLYLINE 611: Not a rectangle
# LWPOLYLINE 612: Is a rectangle
# LWPOLYLINE 613: Not a rectangle
# LWPOLYLINE 614: Not a rectangle
# LWPOLYLINE 615: Not a rectangle
# LWPOLYLINE 616: Not a rectangle
# LWPOLYLINE 617: Is a rectangle
# LWPOLYLINE 618: Is a rectangle
# LWPOLYLINE 619: Is a rectangle
# LWPOLYLINE 620: Not a rectangle
# LWPOLYLINE 621: Not a rectangle
# LWPOLYLINE 622: Not a rectangle
# LWPOLYLINE 623: Not a rectangle
# LWPOLYLINE 624: Is a rectangle
# LWPOLYLINE 625: Is a rectangle
# LWPOLYLINE 626: Not a rectangle
# LWPOLYLINE 627: Not a rectangle
# LWPOLYLINE 628: Not a rectangle
# LWPOLYLINE 629: Not a rectangle
# LWPOLYLINE 630: Is a rectangle
# LWPOLYLINE 631: Is a rectangle
# LWPOLYLINE 632: Not a rectangle
# LWPOLYLINE 633: Not a rectangle
# LWPOLYLINE 634: Not a rectangle
# LWPOLYLINE 635: Not a rectangle
# LWPOLYLINE 636: Is a rectangle
# LWPOLYLINE 637: Is a rectangle
# LWPOLYLINE 638: Not a rectangle
# LWPOLYLINE 639: Not a rectangle
# LWPOLYLINE 640: Not a rectangle
# LWPOLYLINE 641: Not a rectangle
# LWPOLYLINE 642: Is a rectangle
# LWPOLYLINE 643: Is a rectangle
# LWPOLYLINE 644: Not a rectangle
# LWPOLYLINE 645: Not a rectangle
# LWPOLYLINE 646: Not a rectangle
# LWPOLYLINE 647: Not a rectangle
# LWPOLYLINE 648: Is a rectangle
# LWPOLYLINE 649: Is a rectangle
# LWPOLYLINE 650: Not a rectangle
# LWPOLYLINE 651: Not a rectangle
# LWPOLYLINE 652: Not a rectangle
# LWPOLYLINE 653: Not a rectangle
# LWPOLYLINE 654: Is a rectangle
# LWPOLYLINE 655: Is a rectangle
# LWPOLYLINE 656: Not a rectangle
# LWPOLYLINE 657: Not a rectangle
# LWPOLYLINE 658: Not a rectangle
# LWPOLYLINE 659: Not a rectangle
# LWPOLYLINE 660: Is a rectangle
# LWPOLYLINE 661: Is a rectangle
# LWPOLYLINE 662: Not a rectangle
# LWPOLYLINE 663: Not a rectangle
# LWPOLYLINE 664: Not a rectangle
# LWPOLYLINE 665: Not a rectangle
# LWPOLYLINE 666: Is a rectangle
# LWPOLYLINE 667: Is a rectangle
# LWPOLYLINE 668: Not a rectangle
# LWPOLYLINE 669: Not a rectangle
# LWPOLYLINE 670: Not a rectangle
# LWPOLYLINE 671: Not a rectangle
# LWPOLYLINE 672: Is a rectangle
# LWPOLYLINE 673: Is a rectangle
# LWPOLYLINE 674: Not a rectangle
# LWPOLYLINE 675: Not a rectangle
# LWPOLYLINE 676: Not a rectangle
# LWPOLYLINE 677: Not a rectangle
# LWPOLYLINE 678: Is a rectangle
# LWPOLYLINE 679: Is a rectangle
# LWPOLYLINE 680: Not a rectangle
# LWPOLYLINE 681: Not a rectangle
# LWPOLYLINE 682: Not a rectangle
# LWPOLYLINE 683: Not a rectangle
# LWPOLYLINE 684: Is a rectangle
# LWPOLYLINE 685: Is a rectangle
# LWPOLYLINE 686: Not a rectangle
# LWPOLYLINE 687: Not a rectangle
# LWPOLYLINE 688: Not a rectangle
# LWPOLYLINE 689: Not a rectangle
# LWPOLYLINE 690: Is a rectangle
# LWPOLYLINE 691: Is a rectangle
# LWPOLYLINE 692: Not a rectangle
# LWPOLYLINE 693: Not a rectangle
# LWPOLYLINE 694: Not a rectangle
# LWPOLYLINE 695: Not a rectangle
# LWPOLYLINE 696: Is a rectangle
# LWPOLYLINE 697: Is a rectangle
# LWPOLYLINE 698: Not a rectangle
# LWPOLYLINE 699: Not a rectangle
# LWPOLYLINE 700: Not a rectangle
# LWPOLYLINE 701: Not a rectangle
# LWPOLYLINE 702: Is a rectangle
# LWPOLYLINE 703: Is a rectangle
# LWPOLYLINE 704: Not a rectangle
# LWPOLYLINE 705: Not a rectangle
# LWPOLYLINE 706: Not a rectangle
# LWPOLYLINE 707: Not a rectangle
# LWPOLYLINE 708: Is a rectangle
# LWPOLYLINE 709: Is a rectangle
# LWPOLYLINE 710: Not a rectangle
# LWPOLYLINE 711: Not a rectangle
# LWPOLYLINE 712: Not a rectangle
# LWPOLYLINE 713: Not a rectangle
# LWPOLYLINE 714: Is a rectangle
# LWPOLYLINE 715: Is a rectangle
# LWPOLYLINE 716: Not a rectangle
# LWPOLYLINE 717: Not a rectangle
# LWPOLYLINE 718: Not a rectangle
# LWPOLYLINE 719: Not a rectangle
# LWPOLYLINE 720: Is a rectangle
# LWPOLYLINE 721: Is a rectangle
# LWPOLYLINE 722: Is a rectangle
# LWPOLYLINE 723: Not a rectangle
# LWPOLYLINE 724: Not a rectangle
# LWPOLYLINE 725: Is a rectangle
# LWPOLYLINE 726: Not a rectangle
# LWPOLYLINE 727: Is a rectangle
# LWPOLYLINE 728: Not a rectangle
# LWPOLYLINE 729: Not a rectangle
# LWPOLYLINE 730: Not a rectangle
# LWPOLYLINE 731: Not a rectangle
# LWPOLYLINE 732: Is a rectangle
# LWPOLYLINE 733: Not a rectangle
# LWPOLYLINE 734: Not a rectangle
# LWPOLYLINE 735: Not a rectangle
# LWPOLYLINE 736: Not a rectangle
# LWPOLYLINE 737: Is a rectangle
# LWPOLYLINE 738: Is a rectangle
# LWPOLYLINE 739: Is a rectangle
# LWPOLYLINE 740: Not a rectangle
# LWPOLYLINE 741: Not a rectangle
# LWPOLYLINE 742: Not a rectangle
# LWPOLYLINE 743: Not a rectangle
# LWPOLYLINE 744: Is a rectangle
# LWPOLYLINE 745: Is a rectangle
# LWPOLYLINE 746: Not a rectangle
# LWPOLYLINE 747: Not a rectangle
# LWPOLYLINE 748: Not a rectangle
# LWPOLYLINE 749: Not a rectangle
# LWPOLYLINE 750: Is a rectangle
# LWPOLYLINE 751: Is a rectangle
# LWPOLYLINE 752: Not a rectangle
# LWPOLYLINE 753: Not a rectangle
# LWPOLYLINE 754: Not a rectangle
# LWPOLYLINE 755: Not a rectangle
# LWPOLYLINE 756: Is a rectangle
# LWPOLYLINE 757: Is a rectangle
# LWPOLYLINE 758: Not a rectangle
# LWPOLYLINE 759: Not a rectangle
# LWPOLYLINE 760: Not a rectangle
# LWPOLYLINE 761: Not a rectangle
# LWPOLYLINE 762: Is a rectangle
# LWPOLYLINE 763: Is a rectangle
# LWPOLYLINE 764: Not a rectangle
# LWPOLYLINE 765: Not a rectangle
# LWPOLYLINE 766: Not a rectangle
# LWPOLYLINE 767: Not a rectangle
# LWPOLYLINE 768: Is a rectangle
# LWPOLYLINE 769: Is a rectangle
# LWPOLYLINE 770: Not a rectangle
# LWPOLYLINE 771: Not a rectangle
# LWPOLYLINE 772: Not a rectangle
# LWPOLYLINE 773: Not a rectangle
# LWPOLYLINE 774: Is a rectangle
# LWPOLYLINE 775: Is a rectangle
# LWPOLYLINE 776: Not a rectangle
# LWPOLYLINE 777: Not a rectangle
# LWPOLYLINE 778: Not a rectangle
# LWPOLYLINE 779: Not a rectangle
# LWPOLYLINE 780: Is a rectangle
# LWPOLYLINE 781: Is a rectangle
# LWPOLYLINE 782: Not a rectangle
# LWPOLYLINE 783: Not a rectangle
# LWPOLYLINE 784: Not a rectangle
# LWPOLYLINE 785: Not a rectangle
# LWPOLYLINE 786: Is a rectangle
# LWPOLYLINE 787: Is a rectangle
# LWPOLYLINE 788: Not a rectangle
# LWPOLYLINE 789: Not a rectangle
# LWPOLYLINE 790: Not a rectangle
# LWPOLYLINE 791: Not a rectangle
# LWPOLYLINE 792: Is a rectangle
# LWPOLYLINE 793: Is a rectangle
# LWPOLYLINE 794: Not a rectangle
# LWPOLYLINE 795: Not a rectangle
# LWPOLYLINE 796: Not a rectangle
# LWPOLYLINE 797: Not a rectangle
# LWPOLYLINE 798: Is a rectangle
# LWPOLYLINE 799: Is a rectangle
# LWPOLYLINE 800: Not a rectangle
# LWPOLYLINE 801: Not a rectangle
# LWPOLYLINE 802: Not a rectangle
# LWPOLYLINE 803: Not a rectangle
# LWPOLYLINE 804: Is a rectangle
# LWPOLYLINE 805: Is a rectangle
# LWPOLYLINE 806: Not a rectangle
# LWPOLYLINE 807: Not a rectangle
# LWPOLYLINE 808: Not a rectangle
# LWPOLYLINE 809: Not a rectangle
# LWPOLYLINE 810: Is a rectangle
# LWPOLYLINE 811: Is a rectangle
# LWPOLYLINE 812: Not a rectangle
# LWPOLYLINE 813: Not a rectangle
# LWPOLYLINE 814: Not a rectangle
# LWPOLYLINE 815: Not a rectangle
# LWPOLYLINE 816: Is a rectangle
# LWPOLYLINE 817: Is a rectangle
# LWPOLYLINE 818: Not a rectangle
# LWPOLYLINE 819: Not a rectangle
# LWPOLYLINE 820: Not a rectangle
# LWPOLYLINE 821: Not a rectangle
# LWPOLYLINE 822: Is a rectangle
# LWPOLYLINE 823: Is a rectangle
# LWPOLYLINE 824: Not a rectangle
# LWPOLYLINE 825: Not a rectangle
# LWPOLYLINE 826: Not a rectangle
# LWPOLYLINE 827: Not a rectangle
# LWPOLYLINE 828: Is a rectangle
# LWPOLYLINE 829: Is a rectangle
# LWPOLYLINE 830: Not a rectangle
# LWPOLYLINE 831: Not a rectangle
# LWPOLYLINE 832: Not a rectangle
# LWPOLYLINE 833: Not a rectangle
# LWPOLYLINE 834: Is a rectangle
# LWPOLYLINE 835: Is a rectangle
# LWPOLYLINE 836: Not a rectangle
# LWPOLYLINE 837: Not a rectangle
# LWPOLYLINE 838: Not a rectangle
# LWPOLYLINE 839: Not a rectangle
# LWPOLYLINE 840: Is a rectangle
# LWPOLYLINE 841: Is a rectangle
# LWPOLYLINE 842: Is a rectangle
# LWPOLYLINE 843: Not a rectangle
# LWPOLYLINE 844: Not a rectangle
# LWPOLYLINE 845: Is a rectangle
# LWPOLYLINE 846: Not a rectangle
# LWPOLYLINE 847: Is a rectangle
# LWPOLYLINE 848: Not a rectangle
# LWPOLYLINE 849: Not a rectangle
# LWPOLYLINE 850: Not a rectangle
# LWPOLYLINE 851: Not a rectangle
# LWPOLYLINE 852: Is a rectangle
# LWPOLYLINE 853: Is a rectangle
# LWPOLYLINE 854: Is a rectangle
# LWPOLYLINE 855: Not a rectangle
# LWPOLYLINE 856: Not a rectangle
# LWPOLYLINE 857: Is a rectangle
# LWPOLYLINE 858: Not a rectangle
# LWPOLYLINE 859: Is a rectangle
# LWPOLYLINE 860: Not a rectangle
# LWPOLYLINE 861: Not a rectangle
# LWPOLYLINE 862: Not a rectangle
# LWPOLYLINE 863: Not a rectangle
# LWPOLYLINE 864: Is a rectangle
# LWPOLYLINE 865: Not a rectangle
# LWPOLYLINE 866: Not a rectangle
# LWPOLYLINE 867: Not a rectangle
# LWPOLYLINE 868: Not a rectangle
# LWPOLYLINE 869: Is a rectangle
# LWPOLYLINE 870: Is a rectangle
# LWPOLYLINE 871: Is a rectangle
# LWPOLYLINE 872: Not a rectangle
# LWPOLYLINE 873: Not a rectangle
# LWPOLYLINE 874: Not a rectangle
# LWPOLYLINE 875: Not a rectangle
# LWPOLYLINE 876: Is a rectangle
# LWPOLYLINE 877: Is a rectangle
# LWPOLYLINE 878: Not a rectangle
# LWPOLYLINE 879: Not a rectangle
# LWPOLYLINE 880: Not a rectangle
# LWPOLYLINE 881: Not a rectangle
# LWPOLYLINE 882: Is a rectangle
# LWPOLYLINE 883: Is a rectangle
# LWPOLYLINE 884: Not a rectangle
# LWPOLYLINE 885: Not a rectangle
# LWPOLYLINE 886: Not a rectangle
# LWPOLYLINE 887: Not a rectangle
# LWPOLYLINE 888: Is a rectangle
# LWPOLYLINE 889: Is a rectangle
# LWPOLYLINE 890: Not a rectangle
# LWPOLYLINE 891: Not a rectangle
# LWPOLYLINE 892: Not a rectangle
# LWPOLYLINE 893: Not a rectangle
# LWPOLYLINE 894: Is a rectangle
# LWPOLYLINE 895: Is a rectangle
# LWPOLYLINE 896: Not a rectangle
# LWPOLYLINE 897: Not a rectangle
# LWPOLYLINE 898: Not a rectangle
# LWPOLYLINE 899: Not a rectangle
# LWPOLYLINE 900: Is a rectangle
# LWPOLYLINE 901: Is a rectangle
# LWPOLYLINE 902: Not a rectangle
# LWPOLYLINE 903: Not a rectangle
# LWPOLYLINE 904: Not a rectangle
# LWPOLYLINE 905: Not a rectangle
# LWPOLYLINE 906: Is a rectangle
# LWPOLYLINE 907: Is a rectangle
# LWPOLYLINE 908: Not a rectangle
# LWPOLYLINE 909: Not a rectangle
# LWPOLYLINE 910: Not a rectangle
# LWPOLYLINE 911: Not a rectangle
# LWPOLYLINE 912: Is a rectangle
# LWPOLYLINE 913: Is a rectangle
# LWPOLYLINE 914: Not a rectangle
# LWPOLYLINE 915: Not a rectangle
# LWPOLYLINE 916: Not a rectangle
# LWPOLYLINE 917: Not a rectangle
# LWPOLYLINE 918: Is a rectangle
# LWPOLYLINE 919: Is a rectangle
# LWPOLYLINE 920: Not a rectangle
# LWPOLYLINE 921: Not a rectangle
# LWPOLYLINE 922: Not a rectangle
# LWPOLYLINE 923: Not a rectangle
# LWPOLYLINE 924: Is a rectangle
# LWPOLYLINE 925: Is a rectangle
# LWPOLYLINE 926: Not a rectangle
# LWPOLYLINE 927: Not a rectangle
# LWPOLYLINE 928: Not a rectangle
# LWPOLYLINE 929: Not a rectangle
# LWPOLYLINE 930: Is a rectangle
# LWPOLYLINE 931: Is a rectangle
# LWPOLYLINE 932: Not a rectangle
# LWPOLYLINE 933: Not a rectangle
# LWPOLYLINE 934: Not a rectangle
# LWPOLYLINE 935: Not a rectangle
# LWPOLYLINE 936: Is a rectangle
# LWPOLYLINE 937: Is a rectangle
# LWPOLYLINE 938: Not a rectangle
# LWPOLYLINE 939: Not a rectangle
# LWPOLYLINE 940: Not a rectangle
# LWPOLYLINE 941: Not a rectangle
# LWPOLYLINE 942: Is a rectangle
# LWPOLYLINE 943: Is a rectangle
# LWPOLYLINE 944: Not a rectangle
# LWPOLYLINE 945: Not a rectangle
# LWPOLYLINE 946: Not a rectangle
# LWPOLYLINE 947: Not a rectangle
# LWPOLYLINE 948: Is a rectangle
# LWPOLYLINE 949: Is a rectangle
# LWPOLYLINE 950: Not a rectangle
# LWPOLYLINE 951: Not a rectangle
# LWPOLYLINE 952: Not a rectangle
# LWPOLYLINE 953: Not a rectangle
# LWPOLYLINE 954: Is a rectangle
# LWPOLYLINE 955: Is a rectangle
# LWPOLYLINE 956: Not a rectangle
# LWPOLYLINE 957: Not a rectangle
# LWPOLYLINE 958: Not a rectangle
# LWPOLYLINE 959: Not a rectangle
# LWPOLYLINE 960: Is a rectangle
# LWPOLYLINE 961: Is a rectangle
# LWPOLYLINE 962: Not a rectangle
# LWPOLYLINE 963: Not a rectangle
# LWPOLYLINE 964: Not a rectangle
# LWPOLYLINE 965: Not a rectangle
# LWPOLYLINE 966: Is a rectangle
# LWPOLYLINE 967: Is a rectangle
# LWPOLYLINE 968: Not a rectangle
# LWPOLYLINE 969: Not a rectangle
# LWPOLYLINE 970: Not a rectangle
# LWPOLYLINE 971: Not a rectangle
# LWPOLYLINE 972: Is a rectangle
# LWPOLYLINE 973: Not a rectangle
# LWPOLYLINE 974: Not a rectangle
# LWPOLYLINE 975: Not a rectangle
# LWPOLYLINE 976: Not a rectangle
# LWPOLYLINE 977: Not a rectangle
# LWPOLYLINE 978: Not a rectangle
# LWPOLYLINE 979: Not a rectangle
# LWPOLYLINE 980: Not a rectangle
# LWPOLYLINE 981: Not a rectangle
# LWPOLYLINE 982: Not a rectangle
# LWPOLYLINE 983: Not a rectangle
# LWPOLYLINE 984: Not a rectangle
# LWPOLYLINE 985: Not a rectangle
# LWPOLYLINE 986: Not a rectangle
# LWPOLYLINE 987: Not a rectangle
# LWPOLYLINE 988: Not a rectangle
# LWPOLYLINE 989: Not a rectangle
# LWPOLYLINE 990: Not a rectangle
# LWPOLYLINE 991: Not a rectangle
# LWPOLYLINE 992: Not a rectangle
# LWPOLYLINE 993: Not a rectangle
# LWPOLYLINE 994: Not a rectangle
# LWPOLYLINE 995: Not a rectangle
# LWPOLYLINE 996: Not a rectangle
# LWPOLYLINE 997: Not a rectangle
# LWPOLYLINE 998: Not a rectangle
# LWPOLYLINE 999: Not a rectangle
# LWPOLYLINE 1000: Not a rectangle
# LWPOLYLINE 1001: Not a rectangle
# LWPOLYLINE 1002: Not a rectangle
# LWPOLYLINE 1003: Not a rectangle
# LWPOLYLINE 1004: Not a rectangle
# LWPOLYLINE 1005: Not a rectangle
# LWPOLYLINE 1006: Not a rectangle
# LWPOLYLINE 1007: Not a rectangle
# LWPOLYLINE 1008: Not a rectangle
# LWPOLYLINE 1009: Not a rectangle
# LWPOLYLINE 1010: Not a rectangle
# LWPOLYLINE 1011: Not a rectangle
# LWPOLYLINE 1012: Not a rectangle
# LWPOLYLINE 1013: Is a rectangle
# LWPOLYLINE 1014: Not a rectangle
# LWPOLYLINE 1015: Not a rectangle
# LWPOLYLINE 1016: Is a rectangle
# LWPOLYLINE 1017: Is a rectangle
# LWPOLYLINE 1018: Is a rectangle
# LWPOLYLINE 1019: Not a rectangle
# LWPOLYLINE 1020: Is a rectangle
# LWPOLYLINE 1021: Not a rectangle
# LWPOLYLINE 1022: Is a rectangle
# LWPOLYLINE 1023: Not a rectangle
# LWPOLYLINE 1024: Is a rectangle
# LWPOLYLINE 1025: Not a rectangle
# LWPOLYLINE 1026: Is a rectangle
# LWPOLYLINE 1027: Not a rectangle
# LWPOLYLINE 1028: Is a rectangle
# LWPOLYLINE 1029: Not a rectangle
# LWPOLYLINE 1030: Is a rectangle
# LWPOLYLINE 1031: Not a rectangle
# LWPOLYLINE 1032: Is a rectangle
# LWPOLYLINE 1033: Not a rectangle
# LWPOLYLINE 1034: Is a rectangle
# LWPOLYLINE 1035: Not a rectangle
# LWPOLYLINE 1036: Is a rectangle
# LWPOLYLINE 1037: Not a rectangle
# LWPOLYLINE 1038: Is a rectangle
# LWPOLYLINE 1039: Not a rectangle
# LWPOLYLINE 1040: Is a rectangle
# LWPOLYLINE 1041: Not a rectangle
# LWPOLYLINE 1042: Is a rectangle
# LWPOLYLINE 1043: Not a rectangle
# LWPOLYLINE 1044: Is a rectangle
# LWPOLYLINE 1045: Not a rectangle
# LWPOLYLINE 1046: Is a rectangle
# LWPOLYLINE 1047: Not a rectangle
# LWPOLYLINE 1048: Is a rectangle
# LWPOLYLINE 1049: Not a rectangle
# LWPOLYLINE 1050: Is a rectangle
# LWPOLYLINE 1051: Not a rectangle
# LWPOLYLINE 1052: Is a rectangle
# LWPOLYLINE 1053: Is a rectangle
# LWPOLYLINE 1054: Not a rectangle
# LWPOLYLINE 1055: Not a rectangle
# LWPOLYLINE 1056: Is a rectangle
# LWPOLYLINE 1057: Is a rectangle
# LWPOLYLINE 1058: Is a rectangle
# LWPOLYLINE 1059: Not a rectangle
# LWPOLYLINE 1060: Is a rectangle
# LWPOLYLINE 1061: Not a rectangle
# LWPOLYLINE 1062: Is a rectangle
# LWPOLYLINE 1063: Not a rectangle
# LWPOLYLINE 1064: Is a rectangle
# LWPOLYLINE 1065: Not a rectangle
# LWPOLYLINE 1066: Is a rectangle
# LWPOLYLINE 1067: Not a rectangle
# LWPOLYLINE 1068: Is a rectangle
# LWPOLYLINE 1069: Not a rectangle
# LWPOLYLINE 1070: Is a rectangle
# LWPOLYLINE 1071: Not a rectangle
# LWPOLYLINE 1072: Is a rectangle
# LWPOLYLINE 1073: Not a rectangle
# LWPOLYLINE 1074: Is a rectangle
# LWPOLYLINE 1075: Not a rectangle
# LWPOLYLINE 1076: Is a rectangle
# LWPOLYLINE 1077: Not a rectangle
# LWPOLYLINE 1078: Is a rectangle
# LWPOLYLINE 1079: Not a rectangle
# LWPOLYLINE 1080: Is a rectangle
# LWPOLYLINE 1081: Not a rectangle
# LWPOLYLINE 1082: Is a rectangle
# LWPOLYLINE 1083: Not a rectangle
# LWPOLYLINE 1084: Is a rectangle
# LWPOLYLINE 1085: Not a rectangle
# LWPOLYLINE 1086: Is a rectangle
# LWPOLYLINE 1087: Not a rectangle
# LWPOLYLINE 1088: Is a rectangle
# LWPOLYLINE 1089: Not a rectangle
# LWPOLYLINE 1090: Is a rectangle
# LWPOLYLINE 1091: Not a rectangle
# LWPOLYLINE 1092: Is a rectangle
# LWPOLYLINE 1093: Is a rectangle
# LWPOLYLINE 1094: Not a rectangle
# LWPOLYLINE 1095: Not a rectangle
# LWPOLYLINE 1096: Is a rectangle
# LWPOLYLINE 1097: Is a rectangle
# LWPOLYLINE 1098: Is a rectangle
# LWPOLYLINE 1099: Not a rectangle
# LWPOLYLINE 1100: Is a rectangle
# LWPOLYLINE 1101: Not a rectangle
# LWPOLYLINE 1102: Is a rectangle
# LWPOLYLINE 1103: Not a rectangle
# LWPOLYLINE 1104: Is a rectangle
# LWPOLYLINE 1105: Not a rectangle
# LWPOLYLINE 1106: Is a rectangle
# LWPOLYLINE 1107: Not a rectangle
# LWPOLYLINE 1108: Is a rectangle
# LWPOLYLINE 1109: Not a rectangle
# LWPOLYLINE 1110: Is a rectangle
# LWPOLYLINE 1111: Not a rectangle
# LWPOLYLINE 1112: Is a rectangle
# LWPOLYLINE 1113: Not a rectangle
# LWPOLYLINE 1114: Is a rectangle
# LWPOLYLINE 1115: Not a rectangle
# LWPOLYLINE 1116: Is a rectangle
# LWPOLYLINE 1117: Not a rectangle
# LWPOLYLINE 1118: Is a rectangle
# LWPOLYLINE 1119: Not a rectangle
# LWPOLYLINE 1120: Is a rectangle
# LWPOLYLINE 1121: Not a rectangle
# LWPOLYLINE 1122: Is a rectangle
# LWPOLYLINE 1123: Not a rectangle
# LWPOLYLINE 1124: Is a rectangle
# LWPOLYLINE 1125: Not a rectangle
# LWPOLYLINE 1126: Is a rectangle
# LWPOLYLINE 1127: Not a rectangle
# LWPOLYLINE 1128: Is a rectangle
# LWPOLYLINE 1129: Not a rectangle
# LWPOLYLINE 1130: Is a rectangle
# LWPOLYLINE 1131: Not a rectangle
# LWPOLYLINE 1132: Is a rectangle
# LWPOLYLINE 1133: Is a rectangle
# LWPOLYLINE 1134: Not a rectangle
# LWPOLYLINE 1135: Not a rectangle
# LWPOLYLINE 1136: Is a rectangle
# LWPOLYLINE 1137: Is a rectangle
# LWPOLYLINE 1138: Is a rectangle
# LWPOLYLINE 1139: Not a rectangle
# LWPOLYLINE 1140: Is a rectangle
# LWPOLYLINE 1141: Not a rectangle
# LWPOLYLINE 1142: Is a rectangle
# LWPOLYLINE 1143: Not a rectangle
# LWPOLYLINE 1144: Is a rectangle
# LWPOLYLINE 1145: Not a rectangle
# LWPOLYLINE 1146: Is a rectangle
# LWPOLYLINE 1147: Not a rectangle
# LWPOLYLINE 1148: Is a rectangle
# LWPOLYLINE 1149: Not a rectangle
# LWPOLYLINE 1150: Is a rectangle
# LWPOLYLINE 1151: Not a rectangle
# LWPOLYLINE 1152: Is a rectangle
# LWPOLYLINE 1153: Not a rectangle
# LWPOLYLINE 1154: Is a rectangle
# LWPOLYLINE 1155: Not a rectangle
# LWPOLYLINE 1156: Is a rectangle
# LWPOLYLINE 1157: Not a rectangle
# LWPOLYLINE 1158: Is a rectangle
# LWPOLYLINE 1159: Not a rectangle
# LWPOLYLINE 1160: Is a rectangle
# LWPOLYLINE 1161: Not a rectangle
# LWPOLYLINE 1162: Is a rectangle
# LWPOLYLINE 1163: Not a rectangle
# LWPOLYLINE 1164: Is a rectangle
# LWPOLYLINE 1165: Not a rectangle
# LWPOLYLINE 1166: Is a rectangle
# LWPOLYLINE 1167: Not a rectangle
# LWPOLYLINE 1168: Is a rectangle
# LWPOLYLINE 1169: Not a rectangle
# LWPOLYLINE 1170: Is a rectangle
# LWPOLYLINE 1171: Not a rectangle
# LWPOLYLINE 1172: Is a rectangle
# LWPOLYLINE 1173: Is a rectangle
# LWPOLYLINE 1174: Not a rectangle
# LWPOLYLINE 1175: Not a rectangle
# LWPOLYLINE 1176: Is a rectangle
# LWPOLYLINE 1177: Is a rectangle
# LWPOLYLINE 1178: Is a rectangle
# LWPOLYLINE 1179: Not a rectangle
# LWPOLYLINE 1180: Is a rectangle
# LWPOLYLINE 1181: Not a rectangle
# LWPOLYLINE 1182: Is a rectangle
# LWPOLYLINE 1183: Not a rectangle
# LWPOLYLINE 1184: Is a rectangle
# LWPOLYLINE 1185: Not a rectangle
# LWPOLYLINE 1186: Is a rectangle
# LWPOLYLINE 1187: Not a rectangle
# LWPOLYLINE 1188: Is a rectangle
# LWPOLYLINE 1189: Not a rectangle
# LWPOLYLINE 1190: Is a rectangle
# LWPOLYLINE 1191: Not a rectangle
# LWPOLYLINE 1192: Is a rectangle
# LWPOLYLINE 1193: Not a rectangle
# LWPOLYLINE 1194: Is a rectangle
# LWPOLYLINE 1195: Not a rectangle
# LWPOLYLINE 1196: Is a rectangle
# LWPOLYLINE 1197: Not a rectangle
# LWPOLYLINE 1198: Is a rectangle
# LWPOLYLINE 1199: Not a rectangle
# LWPOLYLINE 1200: Is a rectangle
# LWPOLYLINE 1201: Not a rectangle
# LWPOLYLINE 1202: Is a rectangle
# LWPOLYLINE 1203: Not a rectangle
# LWPOLYLINE 1204: Is a rectangle
# LWPOLYLINE 1205: Not a rectangle
# LWPOLYLINE 1206: Is a rectangle
# LWPOLYLINE 1207: Not a rectangle
# LWPOLYLINE 1208: Is a rectangle
# LWPOLYLINE 1209: Not a rectangle
# LWPOLYLINE 1210: Is a rectangle
# LWPOLYLINE 1211: Not a rectangle
# LWPOLYLINE 1212: Is a rectangle
# LWPOLYLINE 1213: Is a rectangle
# LWPOLYLINE 1214: Is a rectangle
# LWPOLYLINE 1215: Not a rectangle
# LWPOLYLINE 1216: Not a rectangle
# LWPOLYLINE 1217: Is a rectangle
# LWPOLYLINE 1218: Not a rectangle
# LWPOLYLINE 1219: Is a rectangle
# LWPOLYLINE 1220: Not a rectangle
# LWPOLYLINE 1221: Not a rectangle
# LWPOLYLINE 1222: Not a rectangle
# LWPOLYLINE 1223: Not a rectangle
# LWPOLYLINE 1224: Is a rectangle
# LWPOLYLINE 1225: Not a rectangle
# LWPOLYLINE 1226: Not a rectangle
# LWPOLYLINE 1227: Not a rectangle
# LWPOLYLINE 1228: Not a rectangle
# LWPOLYLINE 1229: Is a rectangle
# LWPOLYLINE 1230: Is a rectangle
# LWPOLYLINE 1231: Is a rectangle
# LWPOLYLINE 1232: Not a rectangle
# LWPOLYLINE 1233: Not a rectangle
# LWPOLYLINE 1234: Not a rectangle
# LWPOLYLINE 1235: Not a rectangle
# LWPOLYLINE 1236: Is a rectangle
# LWPOLYLINE 1237: Is a rectangle
# LWPOLYLINE 1238: Not a rectangle
# LWPOLYLINE 1239: Not a rectangle
# LWPOLYLINE 1240: Not a rectangle
# LWPOLYLINE 1241: Not a rectangle
# LWPOLYLINE 1242: Is a rectangle
# LWPOLYLINE 1243: Is a rectangle
# LWPOLYLINE 1244: Not a rectangle
# LWPOLYLINE 1245: Not a rectangle
# LWPOLYLINE 1246: Not a rectangle
# LWPOLYLINE 1247: Not a rectangle
# LWPOLYLINE 1248: Is a rectangle
# LWPOLYLINE 1249: Is a rectangle
# LWPOLYLINE 1250: Not a rectangle
# LWPOLYLINE 1251: Not a rectangle
# LWPOLYLINE 1252: Not a rectangle
# LWPOLYLINE 1253: Not a rectangle
# LWPOLYLINE 1254: Is a rectangle
# LWPOLYLINE 1255: Is a rectangle
# LWPOLYLINE 1256: Not a rectangle
# LWPOLYLINE 1257: Not a rectangle
# LWPOLYLINE 1258: Not a rectangle
# LWPOLYLINE 1259: Not a rectangle
# LWPOLYLINE 1260: Is a rectangle
# LWPOLYLINE 1261: Is a rectangle
# LWPOLYLINE 1262: Not a rectangle
# LWPOLYLINE 1263: Not a rectangle
# LWPOLYLINE 1264: Not a rectangle
# LWPOLYLINE 1265: Not a rectangle
# LWPOLYLINE 1266: Is a rectangle
# LWPOLYLINE 1267: Is a rectangle
# LWPOLYLINE 1268: Not a rectangle
# LWPOLYLINE 1269: Not a rectangle
# LWPOLYLINE 1270: Not a rectangle
# LWPOLYLINE 1271: Not a rectangle
# LWPOLYLINE 1272: Is a rectangle
# LWPOLYLINE 1273: Is a rectangle
# LWPOLYLINE 1274: Not a rectangle
# LWPOLYLINE 1275: Not a rectangle
# LWPOLYLINE 1276: Not a rectangle
# LWPOLYLINE 1277: Not a rectangle
# LWPOLYLINE 1278: Is a rectangle
# LWPOLYLINE 1279: Is a rectangle
# LWPOLYLINE 1280: Not a rectangle
# LWPOLYLINE 1281: Not a rectangle
# LWPOLYLINE 1282: Not a rectangle
# LWPOLYLINE 1283: Not a rectangle
# LWPOLYLINE 1284: Is a rectangle
# LWPOLYLINE 1285: Is a rectangle
# LWPOLYLINE 1286: Not a rectangle
# LWPOLYLINE 1287: Not a rectangle
# LWPOLYLINE 1288: Not a rectangle
# LWPOLYLINE 1289: Not a rectangle
# LWPOLYLINE 1290: Is a rectangle
# LWPOLYLINE 1291: Is a rectangle
# LWPOLYLINE 1292: Not a rectangle
# LWPOLYLINE 1293: Not a rectangle
# LWPOLYLINE 1294: Not a rectangle
# LWPOLYLINE 1295: Not a rectangle
# LWPOLYLINE 1296: Is a rectangle
# LWPOLYLINE 1297: Is a rectangle
# LWPOLYLINE 1298: Not a rectangle
# LWPOLYLINE 1299: Not a rectangle
# LWPOLYLINE 1300: Not a rectangle
# LWPOLYLINE 1301: Not a rectangle
# LWPOLYLINE 1302: Is a rectangle
# LWPOLYLINE 1303: Is a rectangle
# LWPOLYLINE 1304: Not a rectangle
# LWPOLYLINE 1305: Not a rectangle
# LWPOLYLINE 1306: Not a rectangle
# LWPOLYLINE 1307: Not a rectangle
# LWPOLYLINE 1308: Is a rectangle
# LWPOLYLINE 1309: Is a rectangle
# LWPOLYLINE 1310: Not a rectangle
# LWPOLYLINE 1311: Not a rectangle
# LWPOLYLINE 1312: Not a rectangle
# LWPOLYLINE 1313: Not a rectangle
# LWPOLYLINE 1314: Is a rectangle
# LWPOLYLINE 1315: Is a rectangle
# LWPOLYLINE 1316: Not a rectangle
# LWPOLYLINE 1317: Not a rectangle
# LWPOLYLINE 1318: Not a rectangle
# LWPOLYLINE 1319: Not a rectangle
# LWPOLYLINE 1320: Is a rectangle
# LWPOLYLINE 1321: Is a rectangle
# LWPOLYLINE 1322: Not a rectangle
# LWPOLYLINE 1323: Not a rectangle
# LWPOLYLINE 1324: Not a rectangle
# LWPOLYLINE 1325: Not a rectangle
# LWPOLYLINE 1326: Is a rectangle
# LWPOLYLINE 1327: Is a rectangle
# LWPOLYLINE 1328: Not a rectangle
# LWPOLYLINE 1329: Not a rectangle
# LWPOLYLINE 1330: Not a rectangle
# LWPOLYLINE 1331: Not a rectangle
# LWPOLYLINE 1332: Is a rectangle
# LWPOLYLINE 1333: Not a rectangle
# LWPOLYLINE 1334: Not a rectangle
# LWPOLYLINE 1335: Not a rectangle
# LWPOLYLINE 1336: Not a rectangle
# LWPOLYLINE 1337: Not a rectangle
# LWPOLYLINE 1338: Not a rectangle
# LWPOLYLINE 1339: Not a rectangle
# LWPOLYLINE 1340: Not a rectangle
# LWPOLYLINE 1341: Not a rectangle
# LWPOLYLINE 1342: Not a rectangle
# LWPOLYLINE 1343: Not a rectangle
# LWPOLYLINE 1344: Not a rectangle
# LWPOLYLINE 1345: Not a rectangle
# LWPOLYLINE 1346: Not a rectangle
# LWPOLYLINE 1347: Not a rectangle
# LWPOLYLINE 1348: Not a rectangle
# LWPOLYLINE 1349: Not a rectangle
# LWPOLYLINE 1350: Not a rectangle
# LWPOLYLINE 1351: Not a rectangle
# LWPOLYLINE 1352: Not a rectangle
# LWPOLYLINE 1353: Not a rectangle
# LWPOLYLINE 1354: Not a rectangle
# LWPOLYLINE 1355: Not a rectangle
# LWPOLYLINE 1356: Not a rectangle
# LWPOLYLINE 1357: Not a rectangle
# LWPOLYLINE 1358: Not a rectangle
# LWPOLYLINE 1359: Not a rectangle
# LWPOLYLINE 1360: Not a rectangle
# LWPOLYLINE 1361: Not a rectangle
# LWPOLYLINE 1362: Not a rectangle
# LWPOLYLINE 1363: Not a rectangle
# LWPOLYLINE 1364: Not a rectangle
# LWPOLYLINE 1365: Not a rectangle
# LWPOLYLINE 1366: Not a rectangle
# LWPOLYLINE 1367: Not a rectangle
# LWPOLYLINE 1368: Not a rectangle
# LWPOLYLINE 1369: Not a rectangle
# LWPOLYLINE 1370: Not a rectangle
# LWPOLYLINE 1371: Not a rectangle
# LWPOLYLINE 1372: Not a rectangle
# LWPOLYLINE 1373: Is a rectangle
# LWPOLYLINE 1374: Not a rectangle
# LWPOLYLINE 1375: Not a rectangle
# LWPOLYLINE 1376: Is a rectangle
# LWPOLYLINE 1377: Is a rectangle
# LWPOLYLINE 1378: Is a rectangle
# LWPOLYLINE 1379: Not a rectangle
# LWPOLYLINE 1380: Is a rectangle
# LWPOLYLINE 1381: Not a rectangle
# LWPOLYLINE 1382: Is a rectangle
# LWPOLYLINE 1383: Not a rectangle
# LWPOLYLINE 1384: Is a rectangle
# LWPOLYLINE 1385: Not a rectangle
# LWPOLYLINE 1386: Is a rectangle
# LWPOLYLINE 1387: Not a rectangle
# LWPOLYLINE 1388: Is a rectangle
# LWPOLYLINE 1389: Not a rectangle
# LWPOLYLINE 1390: Is a rectangle
# LWPOLYLINE 1391: Not a rectangle
# LWPOLYLINE 1392: Is a rectangle
# LWPOLYLINE 1393: Not a rectangle
# LWPOLYLINE 1394: Is a rectangle
# LWPOLYLINE 1395: Not a rectangle
# LWPOLYLINE 1396: Is a rectangle
# LWPOLYLINE 1397: Not a rectangle
# LWPOLYLINE 1398: Is a rectangle
# LWPOLYLINE 1399: Not a rectangle
# LWPOLYLINE 1400: Is a rectangle
# LWPOLYLINE 1401: Not a rectangle
# LWPOLYLINE 1402: Is a rectangle
# LWPOLYLINE 1403: Not a rectangle
# LWPOLYLINE 1404: Is a rectangle
# LWPOLYLINE 1405: Not a rectangle
# LWPOLYLINE 1406: Is a rectangle
# LWPOLYLINE 1407: Not a rectangle
# LWPOLYLINE 1408: Is a rectangle
# LWPOLYLINE 1409: Not a rectangle
# LWPOLYLINE 1410: Is a rectangle
# LWPOLYLINE 1411: Not a rectangle
# LWPOLYLINE 1412: Is a rectangle
# LWPOLYLINE 1413: Is a rectangle
# LWPOLYLINE 1414: Not a rectangle
# LWPOLYLINE 1415: Not a rectangle
# LWPOLYLINE 1416: Is a rectangle
# LWPOLYLINE 1417: Is a rectangle
# LWPOLYLINE 1418: Is a rectangle
# LWPOLYLINE 1419: Not a rectangle
# LWPOLYLINE 1420: Is a rectangle
# LWPOLYLINE 1421: Not a rectangle
# LWPOLYLINE 1422: Is a rectangle
# LWPOLYLINE 1423: Not a rectangle
# LWPOLYLINE 1424: Is a rectangle
# LWPOLYLINE 1425: Not a rectangle
# LWPOLYLINE 1426: Is a rectangle
# LWPOLYLINE 1427: Not a rectangle
# LWPOLYLINE 1428: Is a rectangle
# LWPOLYLINE 1429: Not a rectangle
# LWPOLYLINE 1430: Is a rectangle
# LWPOLYLINE 1431: Not a rectangle
# LWPOLYLINE 1432: Is a rectangle
# LWPOLYLINE 1433: Not a rectangle
# LWPOLYLINE 1434: Is a rectangle
# LWPOLYLINE 1435: Not a rectangle
# LWPOLYLINE 1436: Is a rectangle
# LWPOLYLINE 1437: Not a rectangle
# LWPOLYLINE 1438: Is a rectangle
# LWPOLYLINE 1439: Not a rectangle
# LWPOLYLINE 1440: Is a rectangle
# LWPOLYLINE 1441: Not a rectangle
# LWPOLYLINE 1442: Is a rectangle
# LWPOLYLINE 1443: Not a rectangle
# LWPOLYLINE 1444: Is a rectangle
# LWPOLYLINE 1445: Not a rectangle
# LWPOLYLINE 1446: Is a rectangle
# LWPOLYLINE 1447: Not a rectangle
# LWPOLYLINE 1448: Is a rectangle
# LWPOLYLINE 1449: Not a rectangle
# LWPOLYLINE 1450: Is a rectangle
# LWPOLYLINE 1451: Not a rectangle
# LWPOLYLINE 1452: Is a rectangle
# LWPOLYLINE 1453: Is a rectangle
# LWPOLYLINE 1454: Not a rectangle
# LWPOLYLINE 1455: Not a rectangle
# LWPOLYLINE 1456: Is a rectangle
# LWPOLYLINE 1457: Is a rectangle
# LWPOLYLINE 1458: Is a rectangle
# LWPOLYLINE 1459: Not a rectangle
# LWPOLYLINE 1460: Is a rectangle
# LWPOLYLINE 1461: Not a rectangle
# LWPOLYLINE 1462: Is a rectangle
# LWPOLYLINE 1463: Not a rectangle
# LWPOLYLINE 1464: Is a rectangle
# LWPOLYLINE 1465: Not a rectangle
# LWPOLYLINE 1466: Is a rectangle
# LWPOLYLINE 1467: Not a rectangle
# LWPOLYLINE 1468: Is a rectangle
# LWPOLYLINE 1469: Not a rectangle
# LWPOLYLINE 1470: Is a rectangle
# LWPOLYLINE 1471: Not a rectangle
# LWPOLYLINE 1472: Is a rectangle
# LWPOLYLINE 1473: Not a rectangle
# LWPOLYLINE 1474: Is a rectangle
# LWPOLYLINE 1475: Not a rectangle
# LWPOLYLINE 1476: Is a rectangle
# LWPOLYLINE 1477: Not a rectangle
# LWPOLYLINE 1478: Is a rectangle
# LWPOLYLINE 1479: Not a rectangle
# LWPOLYLINE 1480: Is a rectangle
# LWPOLYLINE 1481: Not a rectangle
# LWPOLYLINE 1482: Is a rectangle
# LWPOLYLINE 1483: Not a rectangle
# LWPOLYLINE 1484: Is a rectangle
# LWPOLYLINE 1485: Not a rectangle
# LWPOLYLINE 1486: Is a rectangle
# LWPOLYLINE 1487: Not a rectangle
# LWPOLYLINE 1488: Is a rectangle
# LWPOLYLINE 1489: Not a rectangle
# LWPOLYLINE 1490: Is a rectangle
# LWPOLYLINE 1491: Not a rectangle
# LWPOLYLINE 1492: Is a rectangle
# LWPOLYLINE 1493: Is a rectangle
# LWPOLYLINE 1494: Not a rectangle
# LWPOLYLINE 1495: Not a rectangle
# LWPOLYLINE 1496: Is a rectangle
# LWPOLYLINE 1497: Is a rectangle
# LWPOLYLINE 1498: Is a rectangle
# LWPOLYLINE 1499: Not a rectangle
# LWPOLYLINE 1500: Is a rectangle
# LWPOLYLINE 1501: Not a rectangle
# LWPOLYLINE 1502: Is a rectangle
# LWPOLYLINE 1503: Not a rectangle
# LWPOLYLINE 1504: Is a rectangle
# ...
# LWPOLYLINE 2872: Not a rectangle
# LWPOLYLINE 2873: Not a rectangle
# LWPOLYLINE 2874: Not a rectangle
# LWPOLYLINE 2875: Not a rectangle
# LWPOLYLINE 2876: Not a rectangle
# LWPOLYLINE 2877: Not a rectangle
# LWPOLYLINE 2878: Not a rectangle
# LWPOLYLINE 2879: Not a rectangle
# LWPOLYLINE 2880: Not a rectangle
# LWPOLYLINE 2881: Not a rectangle
# LWPOLYLINE 2882: Not a rectangle
# LWPOLYLINE 2883: Not a rectangle
# LWPOLYLINE 2884: Not a rectangle
# LWPOLYLINE 2885: Not a rectangle
# LWPOLYLINE 2886: Not a rectangle
# LWPOLYLINE 2887: Not a rectangle
# LWPOLYLINE 2888: Not a rectangle
# LWPOLYLINE 2889: Not a rectangle
# LWPOLYLINE 2890: Not a rectangle
# LWPOLYLINE 2891: Not a rectangle
# LWPOLYLINE 2892: Not a rectangle
# LWPOLYLINE 2893: Not a rectangle
# LWPOLYLINE 2894: Not a rectangle
# LWPOLYLINE 2895: Not a rectangle
# LWPOLYLINE 2896: Not a rectangle
# LWPOLYLINE 2897: Not a rectangle
# LWPOLYLINE 2898: Not a rectangle
# LWPOLYLINE 2899: Not a rectangle
# LWPOLYLINE 2900: Not a rectangle
# LWPOLYLINE 2901: Not a rectangle
# LWPOLYLINE 2902: Not a rectangle
# LWPOLYLINE 2903: Not a rectangle
# LWPOLYLINE 2904: Not a rectangle
# LWPOLYLINE 2905: Not a rectangle
# LWPOLYLINE 2906: Not a rectangle
# LWPOLYLINE 2907: Not a rectangle
# LWPOLYLINE 2908: Not a rectangle
# LWPOLYLINE 2909: Not a rectangle
# LWPOLYLINE 2910: Not a rectangle
# LWPOLYLINE 2911: Not a rectangle
# LWPOLYLINE 2912: Not a rectangle
# LWPOLYLINE 2913: Not a rectangle
# LWPOLYLINE 2914: Not a rectangle
# LWPOLYLINE 2915: Not a rectangle
# LWPOLYLINE 2916: Not a rectangle
# LWPOLYLINE 2917: Not a rectangle
# LWPOLYLINE 2918: Not a rectangle
# LWPOLYLINE 2919: Not a rectangle
# LWPOLYLINE 2920: Not a rectangle
# LWPOLYLINE 2921: Not a rectangle
# LWPOLYLINE 2922: Not a rectangle
# LWPOLYLINE 2923: Not a rectangle
# LWPOLYLINE 2924: Not a rectangle
# LWPOLYLINE 2925: Not a rectangle
# LWPOLYLINE 2926: Not a rectangle
# LWPOLYLINE 2927: Not a rectangle
# LWPOLYLINE 2928: Not a rectangle
# LWPOLYLINE 2929: Not a rectangle
# LWPOLYLINE 2930: Not a rectangle
# LWPOLYLINE 2931: Not a rectangle
# LWPOLYLINE 2932: Not a rectangle
# LWPOLYLINE 2933: Not a rectangle
# LWPOLYLINE 2934: Not a rectangle
# LWPOLYLINE 2935: Not a rectangle
# LWPOLYLINE 2936: Not a rectangle
# LWPOLYLINE 2937: Not a rectangle
# LWPOLYLINE 2938: Not a rectangle
# LWPOLYLINE 2939: Not a rectangle
# LWPOLYLINE 2940: Not a rectangle
# LWPOLYLINE 2941: Not a rectangle
# LWPOLYLINE 2942: Not a rectangle
# LWPOLYLINE 2943: Not a rectangle
# LWPOLYLINE 2944: Not a rectangle
# LWPOLYLINE 2945: Not a rectangle
# LWPOLYLINE 2946: Not a rectangle
# LWPOLYLINE 2947: Not a rectangle
# LWPOLYLINE 2948: Not a rectangle
# LWPOLYLINE 2949: Not a rectangle
# LWPOLYLINE 2950: Not a rectangle
# LWPOLYLINE 2951: Not a rectangle
# LWPOLYLINE 2952: Not a rectangle
# LWPOLYLINE 2953: Not a rectangle
# LWPOLYLINE 2954: Not a rectangle
# LWPOLYLINE 2955: Not a rectangle
# LWPOLYLINE 2956: Not a rectangle
# LWPOLYLINE 2957: Not a rectangle
# LWPOLYLINE 2958: Not a rectangle
# LWPOLYLINE 2959: Not a rectangle
# LWPOLYLINE 2960: Not a rectangle
# LWPOLYLINE 2961: Not a rectangle
# LWPOLYLINE 2962: Not a rectangle
# LWPOLYLINE 2963: Not a rectangle
# LWPOLYLINE 2964: Not a rectangle
# LWPOLYLINE 2965: Not a rectangle
# LWPOLYLINE 2966: Not a rectangle
# LWPOLYLINE 2967: Not a rectangle
# LWPOLYLINE 2968: Not a rectangle
# LWPOLYLINE 2969: Not a rectangle
# LWPOLYLINE 2970: Not a rectangle
# LWPOLYLINE 2971: Not a rectangle
# LWPOLYLINE 2972: Not a rectangle
# LWPOLYLINE 2973: Not a rectangle
# LWPOLYLINE 2974: Not a rectangle
# LWPOLYLINE 2975: Not a rectangle
# LWPOLYLINE 2976: Not a rectangle
# LWPOLYLINE 2977: Not a rectangle
# LWPOLYLINE 2978: Not a rectangle
# LWPOLYLINE 2979: Not a rectangle
# LWPOLYLINE 2980: Not a rectangle
# LWPOLYLINE 2981: Not a rectangle
# LWPOLYLINE 2982: Not a rectangle
# LWPOLYLINE 2983: Not a rectangle
# LWPOLYLINE 2984: Not a rectangle
# LWPOLYLINE 2985: Not a rectangle
# LWPOLYLINE 2986: Not a rectangle
# LWPOLYLINE 2987: Not a rectangle
# LWPOLYLINE 2988: Not a rectangle
# LWPOLYLINE 2989: Not a rectangle
# LWPOLYLINE 2990: Not a rectangle
# LWPOLYLINE 2991: Not a rectangle
# LWPOLYLINE 2992: Not a rectangle
# LWPOLYLINE 2993: Not a rectangle
# LWPOLYLINE 2994: Not a rectangle
# LWPOLYLINE 2995: Not a rectangle
# LWPOLYLINE 2996: Not a rectangle
# LWPOLYLINE 2997: Not a rectangle
# LWPOLYLINE 2998: Not a rectangle
# LWPOLYLINE 2999: Not a rectangle
# LWPOLYLINE 3000: Not a rectangle
# LWPOLYLINE 3001: Not a rectangle
# LWPOLYLINE 3002: Not a rectangle
# LWPOLYLINE 3003: Not a rectangle
# LWPOLYLINE 3004: Not a rectangle
# LWPOLYLINE 3005: Not a rectangle
# LWPOLYLINE 3006: Not a rectangle
# LWPOLYLINE 3007: Not a rectangle
# LWPOLYLINE 3008: Not a rectangle
# LWPOLYLINE 3009: Not a rectangle
# LWPOLYLINE 3010: Not a rectangle
# LWPOLYLINE 3011: Not a rectangle
# LWPOLYLINE 3012: Not a rectangle
# LWPOLYLINE 3013: Not a rectangle
# LWPOLYLINE 3014: Not a rectangle
# LWPOLYLINE 3015: Not a rectangle
# LWPOLYLINE 3016: Not a rectangle
# LWPOLYLINE 3017: Not a rectangle
# LWPOLYLINE 3018: Not a rectangle
# LWPOLYLINE 3019: Not a rectangle
# LWPOLYLINE 3020: Not a rectangle
# LWPOLYLINE 3021: Not a rectangle
# LWPOLYLINE 3022: Not a rectangle
# LWPOLYLINE 3023: Not a rectangle
# LWPOLYLINE 3024: Not a rectangle
# LWPOLYLINE 3025: Not a rectangle
# LWPOLYLINE 3026: Not a rectangle
# LWPOLYLINE 3027: Not a rectangle
# LWPOLYLINE 3028: Not a rectangle
# LWPOLYLINE 3029: Not a rectangle
# LWPOLYLINE 3030: Not a rectangle
# LWPOLYLINE 3031: Not a rectangle
# LWPOLYLINE 3032: Not a rectangle
# LWPOLYLINE 3033: Not a rectangle
# LWPOLYLINE 3034: Not a rectangle
# LWPOLYLINE 3035: Not a rectangle
# LWPOLYLINE 3036: Not a rectangle
# LWPOLYLINE 3037: Not a rectangle
# LWPOLYLINE 3038: Not a rectangle
# LWPOLYLINE 3039: Not a rectangle
# LWPOLYLINE 3040: Not a rectangle
# LWPOLYLINE 3041: Not a rectangle
# LWPOLYLINE 3042: Not a rectangle
# LWPOLYLINE 3043: Not a rectangle
# LWPOLYLINE 3044: Not a rectangle
# LWPOLYLINE 3045: Not a rectangle
# LWPOLYLINE 3046: Not a rectangle
# LWPOLYLINE 3047: Not a rectangle
# LWPOLYLINE 3048: Not a rectangle
# LWPOLYLINE 3049: Not a rectangle
# LWPOLYLINE 3050: Not a rectangle
# LWPOLYLINE 3051: Not a rectangle
# LWPOLYLINE 3052: Not a rectangle
# LWPOLYLINE 3053: Not a rectangle
# LWPOLYLINE 3054: Not a rectangle
# LWPOLYLINE 3055: Not a rectangle
# LWPOLYLINE 3056: Not a rectangle
# LWPOLYLINE 3057: Not a rectangle
# LWPOLYLINE 3058: Not a rectangle
# LWPOLYLINE 3059: Not a rectangle
# LWPOLYLINE 3060: Not a rectangle
# LWPOLYLINE 3061: Not a rectangle
# LWPOLYLINE 3062: Not a rectangle
# LWPOLYLINE 3063: Not a rectangle
# LWPOLYLINE 3064: Not a rectangle
# LWPOLYLINE 3065: Not a rectangle
# LWPOLYLINE 3066: Not a rectangle
# LWPOLYLINE 3067: Not a rectangle
# LWPOLYLINE 3068: Not a rectangle
# LWPOLYLINE 3069: Not a rectangle
# LWPOLYLINE 3070: Not a rectangle
# LWPOLYLINE 3071: Not a rectangle
# LWPOLYLINE 3072: Not a rectangle
# LWPOLYLINE 3073: Not a rectangle
# LWPOLYLINE 3074: Not a rectangle
# LWPOLYLINE 3075: Not a rectangle
# LWPOLYLINE 3076: Not a rectangle
# LWPOLYLINE 3077: Not a rectangle
# LWPOLYLINE 3078: Not a rectangle
# LWPOLYLINE 3079: Not a rectangle
# LWPOLYLINE 3080: Not a rectangle
# LWPOLYLINE 3081: Not a rectangle
# LWPOLYLINE 3082: Not a rectangle
# LWPOLYLINE 3083: Not a rectangle
# LWPOLYLINE 3084: Not a rectangle
# LWPOLYLINE 3085: Not a rectangle
# LWPOLYLINE 3086: Not a rectangle
# LWPOLYLINE 3087: Not a rectangle
# LWPOLYLINE 3088: Not a rectangle
# LWPOLYLINE 3089: Not a rectangle
# LWPOLYLINE 3090: Not a rectangle
# LWPOLYLINE 3091: Not a rectangle
# LWPOLYLINE 3092: Not a rectangle
# LWPOLYLINE 3093: Not a rectangle
# LWPOLYLINE 3094: Not a rectangle
# LWPOLYLINE 3095: Not a rectangle
# LWPOLYLINE 3096: Not a rectangle
# LWPOLYLINE 3097: Not a rectangle
# LWPOLYLINE 3098: Not a rectangle
# LWPOLYLINE 3099: Not a rectangle
# LWPOLYLINE 3100: Not a rectangle
# LWPOLYLINE 3101: Not a rectangle
# LWPOLYLINE 3102: Not a rectangle
# LWPOLYLINE 3103: Not a rectangle
# LWPOLYLINE 3104: Not a rectangle
# LWPOLYLINE 3105: Not a rectangle
# LWPOLYLINE 3106: Not a rectangle
# LWPOLYLINE 3107: Not a rectangle
# LWPOLYLINE 3108: Not a rectangle
# LWPOLYLINE 3109: Not a rectangle
# LWPOLYLINE 3110: Not a rectangle
# LWPOLYLINE 3111: Not a rectangle
# LWPOLYLINE 3112: Not a rectangle
# LWPOLYLINE 3113: Not a rectangle
# LWPOLYLINE 3114: Not a rectangle
# LWPOLYLINE 3115: Not a rectangle
# LWPOLYLINE 3116: Not a rectangle
# LWPOLYLINE 3117: Not a rectangle
# LWPOLYLINE 3118: Not a rectangle
# LWPOLYLINE 3119: Not a rectangle
# LWPOLYLINE 3120: Not a rectangle
# LWPOLYLINE 3121: Not a rectangle
# LWPOLYLINE 3122: Not a rectangle
# LWPOLYLINE 3123: Not a rectangle
# LWPOLYLINE 3124: Not a rectangle
# LWPOLYLINE 3125: Not a rectangle
# LWPOLYLINE 3126: Not a rectangle
# LWPOLYLINE 3127: Not a rectangle
# LWPOLYLINE 3128: Not a rectangle
# LWPOLYLINE 3129: Not a rectangle
# LWPOLYLINE 3130: Not a rectangle
# LWPOLYLINE 3131: Not a rectangle
# LWPOLYLINE 3132: Not a rectangle
# LWPOLYLINE 3133: Not a rectangle
# LWPOLYLINE 3134: Not a rectangle
# LWPOLYLINE 3135: Not a rectangle
# LWPOLYLINE 3136: Not a rectangle
# LWPOLYLINE 3137: Not a rectangle
# LWPOLYLINE 3138: Not a rectangle
# LWPOLYLINE 3139: Not a rectangle
# LWPOLYLINE 3140: Not a rectangle
# LWPOLYLINE 3141: Not a rectangle
# LWPOLYLINE 3142: Not a rectangle
# LWPOLYLINE 3143: Not a rectangle
# LWPOLYLINE 3144: Not a rectangle
# LWPOLYLINE 3145: Not a rectangle
# LWPOLYLINE 3146: Not a rectangle
# LWPOLYLINE 3147: Not a rectangle
# LWPOLYLINE 3148: Not a rectangle
# LWPOLYLINE 3149: Not a rectangle
# LWPOLYLINE 3150: Not a rectangle
# LWPOLYLINE 3151: Not a rectangle
# LWPOLYLINE 3152: Not a rectangle
# LWPOLYLINE 3153: Not a rectangle
# LWPOLYLINE 3154: Not a rectangle
# LWPOLYLINE 3155: Not a rectangle
# LWPOLYLINE 3156: Not a rectangle
# LWPOLYLINE 3157: Not a rectangle
# LWPOLYLINE 3158: Not a rectangle
# LWPOLYLINE 3159: Not a rectangle
# LWPOLYLINE 3160: Not a rectangle
# LWPOLYLINE 3161: Not a rectangle
# LWPOLYLINE 3162: Not a rectangle
# LWPOLYLINE 3163: Not a rectangle
# LWPOLYLINE 3164: Not a rectangle
# LWPOLYLINE 3165: Not a rectangle
# LWPOLYLINE 3166: Not a rectangle
# LWPOLYLINE 3167: Not a rectangle
# LWPOLYLINE 3168: Not a rectangle
# LWPOLYLINE 3169: Not a rectangle
# LWPOLYLINE 3170: Not a rectangle
# LWPOLYLINE 3171: Not a rectangle
# LWPOLYLINE 3172: Not a rectangle
# LWPOLYLINE 3173: Not a rectangle
# LWPOLYLINE 3174: Not a rectangle
# LWPOLYLINE 3175: Not a rectangle
# LWPOLYLINE 3176: Not a rectangle
# LWPOLYLINE 3177: Not a rectangle
# LWPOLYLINE 3178: Not a rectangle
# LWPOLYLINE 3179: Not a rectangle
# LWPOLYLINE 3180: Not a rectangle
# LWPOLYLINE 3181: Not a rectangle
# LWPOLYLINE 3182: Not a rectangle
# LWPOLYLINE 3183: Not a rectangle
# LWPOLYLINE 3184: Not a rectangle
# LWPOLYLINE 3185: Not a rectangle
# LWPOLYLINE 3186: Not a rectangle
# LWPOLYLINE 3187: Not a rectangle
# LWPOLYLINE 3188: Not a rectangle
# LWPOLYLINE 3189: Not a rectangle
# LWPOLYLINE 3190: Not a rectangle
# LWPOLYLINE 3191: Not a rectangle
# LWPOLYLINE 3192: Not a rectangle
# LWPOLYLINE 3193: Not a rectangle
# LWPOLYLINE 3194: Not a rectangle
# LWPOLYLINE 3195: Not a rectangle
# LWPOLYLINE 3196: Not a rectangle
# LWPOLYLINE 3197: Not a rectangle
# LWPOLYLINE 3198: Not a rectangle
# LWPOLYLINE 3199: Not a rectangle
# LWPOLYLINE 3200: Not a rectangle
# LWPOLYLINE 3201: Not a rectangle
# LWPOLYLINE 3202: Not a rectangle
# LWPOLYLINE 3203: Not a rectangle
# LWPOLYLINE 3204: Not a rectangle
# LWPOLYLINE 3205: Not a rectangle
# LWPOLYLINE 3206: Not a rectangle
# LWPOLYLINE 3207: Not a rectangle
# LWPOLYLINE 3208: Not a rectangle
# LWPOLYLINE 3209: Not a rectangle
# LWPOLYLINE 3210: Not a rectangle
# LWPOLYLINE 3211: Not a rectangle
# LWPOLYLINE 3212: Not a rectangle
# LWPOLYLINE 3213: Not a rectangle
# LWPOLYLINE 3214: Not a rectangle
# LWPOLYLINE 3215: Not a rectangle
# LWPOLYLINE 3216: Not a rectangle
# LWPOLYLINE 3217: Not a rectangle
# LWPOLYLINE 3218: Not a rectangle
# LWPOLYLINE 3219: Not a rectangle
# LWPOLYLINE 3220: Not a rectangle
# LWPOLYLINE 3221: Not a rectangle
# LWPOLYLINE 3222: Not a rectangle
# LWPOLYLINE 3223: Not a rectangle
# LWPOLYLINE 3224: Not a rectangle
# LWPOLYLINE 3225: Not a rectangle
# LWPOLYLINE 3226: Not a rectangle
# LWPOLYLINE 3227: Not a rectangle
# LWPOLYLINE 3228: Not a rectangle
# LWPOLYLINE 3229: Not a rectangle
# LWPOLYLINE 3230: Not a rectangle
# LWPOLYLINE 3231: Not a rectangle
# LWPOLYLINE 3232: Not a rectangle
# LWPOLYLINE 3233: Not a rectangle
# LWPOLYLINE 3234: Not a rectangle
# LWPOLYLINE 3235: Not a rectangle
# LWPOLYLINE 3236: Not a rectangle
# LWPOLYLINE 3237: Not a rectangle
# LWPOLYLINE 3238: Not a rectangle
# LWPOLYLINE 3239: Not a rectangle
# LWPOLYLINE 3240: Not a rectangle
# LWPOLYLINE 3241: Not a rectangle
# LWPOLYLINE 3242: Not a rectangle
# LWPOLYLINE 3243: Not a rectangle
# LWPOLYLINE 3244: Not a rectangle
# LWPOLYLINE 3245: Not a rectangle
# LWPOLYLINE 3246: Not a rectangle
# LWPOLYLINE 3247: Not a rectangle
# LWPOLYLINE 3248: Not a rectangle
# LWPOLYLINE 3249: Not a rectangle
# LWPOLYLINE 3250: Not a rectangle
# LWPOLYLINE 3251: Not a rectangle
# LWPOLYLINE 3252: Not a rectangle
# LWPOLYLINE 3253: Not a rectangle
# LWPOLYLINE 3254: Not a rectangle
# LWPOLYLINE 3255: Not a rectangle
# LWPOLYLINE 3256: Not a rectangle
# LWPOLYLINE 3257: Not a rectangle
# LWPOLYLINE 3258: Not a rectangle
# LWPOLYLINE 3259: Not a rectangle
# LWPOLYLINE 3260: Not a rectangle
# LWPOLYLINE 3261: Not a rectangle
# LWPOLYLINE 3262: Not a rectangle
# LWPOLYLINE 3263: Not a rectangle
# LWPOLYLINE 3264: Not a rectangle
# LWPOLYLINE 3265: Not a rectangle
# LWPOLYLINE 3266: Not a rectangle
# LWPOLYLINE 3267: Not a rectangle
# LWPOLYLINE 3268: Not a rectangle
# LWPOLYLINE 3269: Not a rectangle
# LWPOLYLINE 3270: Not a rectangle
# LWPOLYLINE 3271: Not a rectangle
# LWPOLYLINE 3272: Not a rectangle
# LWPOLYLINE 3273: Not a rectangle
# LWPOLYLINE 3274: Not a rectangle
# LWPOLYLINE 3275: Not a rectangle
# LWPOLYLINE 3276: Not a rectangle
# LWPOLYLINE 3277: Not a rectangle
# LWPOLYLINE 3278: Not a rectangle
# LWPOLYLINE 3279: Not a rectangle
# LWPOLYLINE 3280: Not a rectangle
# LWPOLYLINE 3281: Not a rectangle
# LWPOLYLINE 3282: Not a rectangle
# LWPOLYLINE 3283: Not a rectangle
# LWPOLYLINE 3284: Not a rectangle
# LWPOLYLINE 3285: Not a rectangle
# LWPOLYLINE 3286: Not a rectangle
# LWPOLYLINE 3287: Not a rectangle
# LWPOLYLINE 3288: Not a rectangle
# LWPOLYLINE 3289: Not a rectangle
# LWPOLYLINE 3290: Not a rectangle
# LWPOLYLINE 3291: Not a rectangle
# LWPOLYLINE 3292: Not a rectangle
# LWPOLYLINE 3293: Not a rectangle
# LWPOLYLINE 3294: Not a rectangle
# LWPOLYLINE 3295: Not a rectangle
# LWPOLYLINE 3296: Not a rectangle
# LWPOLYLINE 3297: Not a rectangle
# LWPOLYLINE 3298: Not a rectangle
# LWPOLYLINE 3299: Not a rectangle
# LWPOLYLINE 3300: Not a rectangle
# LWPOLYLINE 3301: Not a rectangle
# LWPOLYLINE 3302: Not a rectangle
# LWPOLYLINE 3303: Not a rectangle
# LWPOLYLINE 3304: Not a rectangle
# LWPOLYLINE 3305: Not a rectangle
# LWPOLYLINE 3306: Not a rectangle
# LWPOLYLINE 3307: Not a rectangle
# LWPOLYLINE 3308: Not a rectangle
# LWPOLYLINE 3309: Not a rectangle
# LWPOLYLINE 3310: Not a rectangle
# LWPOLYLINE 3311: Not a rectangle
# LWPOLYLINE 3312: Not a rectangle
# LWPOLYLINE 3313: Not a rectangle
# LWPOLYLINE 3314: Not a rectangle
# LWPOLYLINE 3315: Not a rectangle
# LWPOLYLINE 3316: Not a rectangle
# LWPOLYLINE 3317: Not a rectangle
# LWPOLYLINE 3318: Not a rectangle
# LWPOLYLINE 3319: Not a rectangle
# LWPOLYLINE 3320: Not a rectangle
# LWPOLYLINE 3321: Not a rectangle
# LWPOLYLINE 3322: Not a rectangle
# LWPOLYLINE 3323: Not a rectangle
# LWPOLYLINE 3324: Not a rectangle
# LWPOLYLINE 3325: Not a rectangle
# LWPOLYLINE 3326: Not a rectangle
# LWPOLYLINE 3327: Not a rectangle
# LWPOLYLINE 3328: Not a rectangle
# LWPOLYLINE 3329: Not a rectangle
# LWPOLYLINE 3330: Not a rectangle
# LWPOLYLINE 3331: Not a rectangle
# LWPOLYLINE 3332: Not a rectangle
# LWPOLYLINE 3333: Not a rectangle
# LWPOLYLINE 3334: Not a rectangle
# LWPOLYLINE 3335: Not a rectangle
# LWPOLYLINE 3336: Not a rectangle
# LWPOLYLINE 3337: Not a rectangle
# LWPOLYLINE 3338: Not a rectangle
# LWPOLYLINE 3339: Not a rectangle
# LWPOLYLINE 3340: Not a rectangle
# LWPOLYLINE 3341: Not a rectangle
# LWPOLYLINE 3342: Not a rectangle
# LWPOLYLINE 3343: Not a rectangle
# LWPOLYLINE 3344: Not a rectangle
# LWPOLYLINE 3345: Not a rectangle
# LWPOLYLINE 3346: Not a rectangle
# LWPOLYLINE 3347: Not a rectangle
# LWPOLYLINE 3348: Not a rectangle
# LWPOLYLINE 3349: Not a rectangle
# LWPOLYLINE 3350: Not a rectangle
# LWPOLYLINE 3351: Not a rectangle
# LWPOLYLINE 3352: Not a rectangle
# LWPOLYLINE 3353: Not a rectangle
# LWPOLYLINE 3354: Not a rectangle
# LWPOLYLINE 3355: Not a rectangle

# %%
def check_rectangle_properties(polyline):
    """
    Checks if a polyline rectangle is horizontal or vertical, finds its center coordinate,
    and calculates its average height and width.
    
    :param polyline: Dictionary containing points of the polyline.
    :return: A tuple (orientation, center, average_height, average_width) if valid, otherwise None.
             orientation: 'Horizontal' or 'Vertical'
             center: (x_center, y_center)
             average_height: The height of the rectangle
             average_width: The width of the rectangle
    """
    points = polyline["points"]  # List of (x, y) tuples

    # Ensure the polyline has exactly 4 vertices and is closed
    if len(points) != 4 or not polyline["is_closed"]:
        return None  # Not a valid rectangle
    
    # Find the min and max x and y coordinates
    min_x = min(point[0] for point in points)
    max_x = max(point[0] for point in points)
    min_y = min(point[1] for point in points)
    max_y = max(point[1] for point in points)
    
    # Calculate the differences
    x_diff = max_x - min_x
    y_diff = max_y - min_y

    # calculate the gradient
    gradient= min_y/min_x
    
    # Calculate the center coordinate
    x_center = (min_x + max_x) / 2
    y_center = (min_y + max_y) / 2
    center = (x_center, y_center)

    # Calculate height and width
    average_height = y_diff
    average_width = x_diff

    # Determine orientation
    if y_diff > x_diff:
        orientation = "Vertical"
        cellcenter = (x_center,(max_y-((max_y-y_center)/2)))
    else:
        orientation = "Horizontal"
        cellcenter = (max_x-((max_x-x_center)/2),y_center)

    
    return orientation, center, average_height, average_width, cellcenter, gradient

# Iterate through all LWPOLYLINEs, validate if rectangle, and check properties
for idx, polyline in enumerate(lwpolylines, start=1):
    if validate_rectangle(polyline):  # Using the validate_rectangle function from earlier
        orientation, center, avg_height, avg_width, cellcenter, gradient = check_rectangle_properties(polyline)
        print(f"LWPOLYLINE {idx}:")
        print(f"  Orientation: {orientation}")
        print(f"  Center: {center}")
        print(f"  Average Height: {avg_height}")
        print(f"  Average Width: {avg_width}")
        print(f"  Cell center: {cellcenter}")
        print(f"  Gradient: {gradient}")
    else:
        print(f"LWPOLYLINE {idx}: Not a rectangle")
# Out:
# LWPOLYLINE 1:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 22279.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 22279.000000000524)
#   Gradient: 0.1674512035362851
# LWPOLYLINE 2: Not a rectangle
# LWPOLYLINE 3: Not a rectangle
# LWPOLYLINE 4: Not a rectangle
# LWPOLYLINE 5: Not a rectangle
# LWPOLYLINE 6:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 22279.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 22279.000000000524)
#   Gradient: 0.1523232433090879
# LWPOLYLINE 7: Not a rectangle
# LWPOLYLINE 8: Not a rectangle
# LWPOLYLINE 9: Not a rectangle
# LWPOLYLINE 10: Not a rectangle
# LWPOLYLINE 11:
#   Orientation: Horizontal
#   Center: (141364.09411460886, 23438.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704581991
#   Cell center: (141946.54479075436, 23438.000000000524)
#   Gradient: 0.16313218035979798
# LWPOLYLINE 12:
#   Orientation: Horizontal
#   Center: (143703.8831145391, 23438.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045824856
#   Cell center: (144286.3337906847, 23438.000000000524)
#   Gradient: 0.16045435232692268
# LWPOLYLINE 13:
#   Orientation: Horizontal
#   Center: (130826.55526387852, 24597.00000000054)
#   Average Height: 1134.000000000029
#   Average Width: 2329.802704582471
#   Cell center: (131409.00594002413, 24597.00000000054)
#   Gradient: 0.18532850133460368
# LWPOLYLINE 14:
#   Orientation: Horizontal
#   Center: (133166.34426380857, 24597.00000000054)
#   Average Height: 1134.000000000029
#   Average Width: 2329.8027045823983
#   Cell center: (133748.79493995418, 24597.00000000054)
#   Gradient: 0.18204346460143023
# LWPOLYLINE 15: Not a rectangle
# LWPOLYLINE 16: Not a rectangle
# LWPOLYLINE 17:
#   Orientation: Horizontal
#   Center: (141364.09411460886, 24597.00000000054)
#   Average Height: 1134.000000000029
#   Average Width: 2329.802704581991
#   Cell center: (141946.54479075436, 24597.00000000054)
#   Gradient: 0.17139898972698794
# LWPOLYLINE 18: Not a rectangle
# LWPOLYLINE 19:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 21120.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 21120.000000000524)
#   Gradient: 0.15851255463712566
# LWPOLYLINE 20: Not a rectangle
# LWPOLYLINE 21: Not a rectangle
# LWPOLYLINE 22: Not a rectangle
# LWPOLYLINE 23: Not a rectangle
# LWPOLYLINE 24:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 21120.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 21120.000000000524)
#   Gradient: 0.14419213429125313
# LWPOLYLINE 25:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 19961.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 19961.000000000524)
#   Gradient: 0.14957390573796622
# LWPOLYLINE 26: Not a rectangle
# LWPOLYLINE 27: Not a rectangle
# LWPOLYLINE 28: Not a rectangle
# LWPOLYLINE 29: Not a rectangle
# LWPOLYLINE 30:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 19961.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 19961.000000000524)
#   Gradient: 0.13606102527341835
# LWPOLYLINE 31:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 18727.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 18727.000000000524)
#   Gradient: 0.14005682830779992
# LWPOLYLINE 32: Not a rectangle
# LWPOLYLINE 33: Not a rectangle
# LWPOLYLINE 34: Not a rectangle
# LWPOLYLINE 35: Not a rectangle
# LWPOLYLINE 36:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 18727.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 18727.000000000524)
#   Gradient: 0.1274037444036961
# LWPOLYLINE 37:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 17568.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 17568.000000000524)
#   Gradient: 0.13111817940864048
# LWPOLYLINE 38: Not a rectangle
# LWPOLYLINE 39: Not a rectangle
# LWPOLYLINE 40: Not a rectangle
# LWPOLYLINE 41: Not a rectangle
# LWPOLYLINE 42:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 17568.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 17568.000000000524)
#   Gradient: 0.11927263538586132
# LWPOLYLINE 43:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 16409.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 16409.000000000524)
#   Gradient: 0.12217953050948104
# LWPOLYLINE 44: Not a rectangle
# LWPOLYLINE 45: Not a rectangle
# LWPOLYLINE 46: Not a rectangle
# LWPOLYLINE 47: Not a rectangle
# LWPOLYLINE 48:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 16409.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 16409.000000000524)
#   Gradient: 0.11114152636802653
# LWPOLYLINE 49:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 15250.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 15250.000000000524)
#   Gradient: 0.1132408816103216
# LWPOLYLINE 50: Not a rectangle
# LWPOLYLINE 51: Not a rectangle
# LWPOLYLINE 52: Not a rectangle
# LWPOLYLINE 53: Not a rectangle
# LWPOLYLINE 54:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 15250.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 15250.000000000524)
#   Gradient: 0.10301041735019176
# LWPOLYLINE 55:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 14091.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 14091.000000000524)
#   Gradient: 0.10430223271116217
# LWPOLYLINE 56: Not a rectangle
# LWPOLYLINE 57: Not a rectangle
# LWPOLYLINE 58: Not a rectangle
# LWPOLYLINE 59: Not a rectangle
# LWPOLYLINE 60:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 14091.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 14091.000000000524)
#   Gradient: 0.09487930833235698
# LWPOLYLINE 61:
#   Orientation: Horizontal
#   Center: (130826.55526387822, 12932.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582704
#   Cell center: (131409.0059400239, 12932.000000000524)
#   Gradient: 0.09536358381200287
# LWPOLYLINE 62: Not a rectangle
# LWPOLYLINE 63: Not a rectangle
# LWPOLYLINE 64: Not a rectangle
# LWPOLYLINE 65: Not a rectangle
# LWPOLYLINE 66:
#   Orientation: Horizontal
#   Center: (143703.88311453874, 12932.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.3337906843, 12932.000000000524)
#   Gradient: 0.08674819931452234
# LWPOLYLINE 67:
#   Orientation: Horizontal
#   Center: (130826.55526387822, 11773.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582704
#   Cell center: (131409.0059400239, 11773.000000000524)
#   Gradient: 0.08642493491284342
# LWPOLYLINE 68: Not a rectangle
# LWPOLYLINE 69: Not a rectangle
# LWPOLYLINE 70: Not a rectangle
# LWPOLYLINE 71: Not a rectangle
# LWPOLYLINE 72:
#   Orientation: Horizontal
#   Center: (143703.88311453874, 11773.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.3337906843, 11773.000000000524)
#   Gradient: 0.07861709029668755
# LWPOLYLINE 73:
#   Orientation: Horizontal
#   Center: (130826.55526387822, 10614.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582704
#   Cell center: (131409.0059400239, 10614.000000000524)
#   Gradient: 0.07748628601368396
# LWPOLYLINE 74: Not a rectangle
# LWPOLYLINE 75: Not a rectangle
# LWPOLYLINE 76: Not a rectangle
# LWPOLYLINE 77: Not a rectangle
# LWPOLYLINE 78:
#   Orientation: Horizontal
#   Center: (143703.88311453874, 10614.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.3337906843, 10614.000000000524)
#   Gradient: 0.07048598127885276
# LWPOLYLINE 79:
#   Orientation: Horizontal
#   Center: (130826.55526387822, 9455.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582704
#   Cell center: (131409.0059400239, 9455.000000000524)
#   Gradient: 0.06854763711452451
# LWPOLYLINE 80: Not a rectangle
# LWPOLYLINE 81: Not a rectangle
# LWPOLYLINE 82: Not a rectangle
# LWPOLYLINE 83: Not a rectangle
# LWPOLYLINE 84:
#   Orientation: Horizontal
#   Center: (143703.88311453874, 9455.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.3337906843, 9455.000000000524)
#   Gradient: 0.06235487226101798
# LWPOLYLINE 85:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 8296.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 8296.000000000524)
#   Gradient: 0.059608988215364964
# LWPOLYLINE 86: Not a rectangle
# LWPOLYLINE 87: Not a rectangle
# LWPOLYLINE 88: Not a rectangle
# LWPOLYLINE 89: Not a rectangle
# LWPOLYLINE 90:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 8296.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 8296.000000000524)
#   Gradient: 0.054223763243183114
# LWPOLYLINE 91:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 7137.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 7137.000000000524)
#   Gradient: 0.05067033931620552
# LWPOLYLINE 92: Not a rectangle
# LWPOLYLINE 93: Not a rectangle
# LWPOLYLINE 94: Not a rectangle
# LWPOLYLINE 95: Not a rectangle
# LWPOLYLINE 96:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 7137.000000000524)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 7137.000000000524)
#   Gradient: 0.04609265422534834
# LWPOLYLINE 97:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 5203.0)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 5203.0)
#   Gradient: 0.03575459559663776
# LWPOLYLINE 98: Not a rectangle
# LWPOLYLINE 99: Not a rectangle
# LWPOLYLINE 100: Not a rectangle
# LWPOLYLINE 101: Not a rectangle
# LWPOLYLINE 102:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 5203.0)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 5203.0)
#   Gradient: 0.0325244360713391
# LWPOLYLINE 103:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 4044.0)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 4044.0)
#   Gradient: 0.02681594669747832
# LWPOLYLINE 104: Not a rectangle
# LWPOLYLINE 105: Not a rectangle
# LWPOLYLINE 106: Not a rectangle
# LWPOLYLINE 107: Not a rectangle
# LWPOLYLINE 108:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 4044.0)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 4044.0)
#   Gradient: 0.024393327053504322
# LWPOLYLINE 109:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 2885.0)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 2885.0)
#   Gradient: 0.01787729779831888
# LWPOLYLINE 110: Not a rectangle
# LWPOLYLINE 111: Not a rectangle
# LWPOLYLINE 112: Not a rectangle
# LWPOLYLINE 113: Not a rectangle
# LWPOLYLINE 114:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 2885.0)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 2885.0)
#   Gradient: 0.01626221803566955
# LWPOLYLINE 115:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 1726.0)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 1726.0)
#   Gradient: 0.00893864889915944
# LWPOLYLINE 116: Not a rectangle
# LWPOLYLINE 117: Not a rectangle
# LWPOLYLINE 118: Not a rectangle
# LWPOLYLINE 119: Not a rectangle
# LWPOLYLINE 120:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 1726.0)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 1726.0)
#   Gradient: 0.008131109017834775
# LWPOLYLINE 121:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 567.0)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 567.0)
#   Gradient: 0.0
# LWPOLYLINE 122: Not a rectangle
# LWPOLYLINE 123: Not a rectangle
# LWPOLYLINE 124: Not a rectangle
# LWPOLYLINE 125: Not a rectangle
# LWPOLYLINE 126:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 567.0)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 567.0)
#   Gradient: 0.0
# LWPOLYLINE 127:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 45834.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 45834.00000000035)
#   Gradient: 0.3491163241745069
# LWPOLYLINE 128: Not a rectangle
# LWPOLYLINE 129: Not a rectangle
# LWPOLYLINE 130: Not a rectangle
# LWPOLYLINE 131: Not a rectangle
# LWPOLYLINE 132:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 45834.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 45834.00000000035)
#   Gradient: 0.31757628292521967
# LWPOLYLINE 133: Not a rectangle
# LWPOLYLINE 134: Not a rectangle
# LWPOLYLINE 135: Not a rectangle
# LWPOLYLINE 136: Not a rectangle
# LWPOLYLINE 137:
#   Orientation: Horizontal
#   Center: (141364.09411460886, 46993.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704581991
#   Cell center: (141946.54479075436, 46993.00000000035)
#   Gradient: 0.3311431334608835
# LWPOLYLINE 138:
#   Orientation: Horizontal
#   Center: (143703.8831145391, 46993.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045824856
#   Cell center: (144286.3337906847, 46993.00000000035)
#   Gradient: 0.3257073919430544
# LWPOLYLINE 139:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 44675.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 44675.00000000035)
#   Gradient: 0.3401776752753474
# LWPOLYLINE 140: Not a rectangle
# LWPOLYLINE 141: Not a rectangle
# LWPOLYLINE 142: Not a rectangle
# LWPOLYLINE 143: Not a rectangle
# LWPOLYLINE 144:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 44675.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 44675.00000000035)
#   Gradient: 0.30944517390738485
# LWPOLYLINE 145:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 43516.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 43516.00000000035)
#   Gradient: 0.331239026376188
# LWPOLYLINE 146: Not a rectangle
# LWPOLYLINE 147: Not a rectangle
# LWPOLYLINE 148: Not a rectangle
# LWPOLYLINE 149: Not a rectangle
# LWPOLYLINE 150:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 43516.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 43516.00000000035)
#   Gradient: 0.3013140648895501
# LWPOLYLINE 151:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 41982.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 41982.00000000055)
#   Gradient: 0.3194082348219953
# LWPOLYLINE 152: Not a rectangle
# LWPOLYLINE 153: Not a rectangle
# LWPOLYLINE 154: Not a rectangle
# LWPOLYLINE 155: Not a rectangle
# LWPOLYLINE 156:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 41982.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 41982.00000000055)
#   Gradient: 0.2905520966122789
# LWPOLYLINE 157:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 40823.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 40823.00000000055)
#   Gradient: 0.31046958592283586
# LWPOLYLINE 158: Not a rectangle
# LWPOLYLINE 159: Not a rectangle
# LWPOLYLINE 160: Not a rectangle
# LWPOLYLINE 161: Not a rectangle
# LWPOLYLINE 162:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 40823.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 40823.00000000055)
#   Gradient: 0.2824209875944441
# LWPOLYLINE 163:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 39664.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 39664.00000000055)
#   Gradient: 0.30153093702367645
# LWPOLYLINE 164: Not a rectangle
# LWPOLYLINE 165: Not a rectangle
# LWPOLYLINE 166: Not a rectangle
# LWPOLYLINE 167: Not a rectangle
# LWPOLYLINE 168:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 39664.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 39664.00000000055)
#   Gradient: 0.27428987857660936
# LWPOLYLINE 169:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 38505.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 38505.00000000055)
#   Gradient: 0.29259228812451704
# LWPOLYLINE 170: Not a rectangle
# LWPOLYLINE 171: Not a rectangle
# LWPOLYLINE 172: Not a rectangle
# LWPOLYLINE 173: Not a rectangle
# LWPOLYLINE 174:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 38505.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 38505.00000000055)
#   Gradient: 0.26615876955877454
# LWPOLYLINE 175:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 37346.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 37346.00000000055)
#   Gradient: 0.2836536392253576
# LWPOLYLINE 176: Not a rectangle
# LWPOLYLINE 177: Not a rectangle
# LWPOLYLINE 178: Not a rectangle
# LWPOLYLINE 179: Not a rectangle
# LWPOLYLINE 180:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 37346.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 37346.00000000055)
#   Gradient: 0.2580276605409398
# LWPOLYLINE 181:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 36187.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 36187.00000000055)
#   Gradient: 0.2747149903261986
# LWPOLYLINE 182: Not a rectangle
# LWPOLYLINE 183: Not a rectangle
# LWPOLYLINE 184: Not a rectangle
# LWPOLYLINE 185: Not a rectangle
# LWPOLYLINE 186:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 36187.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 36187.00000000055)
#   Gradient: 0.2498965515231054
# LWPOLYLINE 187:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 35028.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 35028.00000000055)
#   Gradient: 0.26577634142703915
# LWPOLYLINE 188: Not a rectangle
# LWPOLYLINE 189: Not a rectangle
# LWPOLYLINE 190: Not a rectangle
# LWPOLYLINE 191: Not a rectangle
# LWPOLYLINE 192:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 35028.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 35028.00000000055)
#   Gradient: 0.24176544250527063
# LWPOLYLINE 193:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 33869.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 33869.00000000055)
#   Gradient: 0.25683769252787975
# LWPOLYLINE 194: Not a rectangle
# LWPOLYLINE 195: Not a rectangle
# LWPOLYLINE 196: Not a rectangle
# LWPOLYLINE 197: Not a rectangle
# LWPOLYLINE 198:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 33869.00000000055)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 33869.00000000055)
#   Gradient: 0.23363433348743584
# LWPOLYLINE 199:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 32710.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 32710.000000000553)
#   Gradient: 0.24789904362872028
# LWPOLYLINE 200: Not a rectangle
# LWPOLYLINE 201: Not a rectangle
# LWPOLYLINE 202: Not a rectangle
# LWPOLYLINE 203: Not a rectangle
# LWPOLYLINE 204:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 32710.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 32710.000000000553)
#   Gradient: 0.22550322446960108
# LWPOLYLINE 205:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 31551.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 31551.000000000553)
#   Gradient: 0.23896039472956046
# LWPOLYLINE 206: Not a rectangle
# LWPOLYLINE 207: Not a rectangle
# LWPOLYLINE 208: Not a rectangle
# LWPOLYLINE 209: Not a rectangle
# LWPOLYLINE 210:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 31551.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 31551.000000000553)
#   Gradient: 0.217372115451766
# LWPOLYLINE 211:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 30392.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 30392.000000000553)
#   Gradient: 0.23002174583040105
# LWPOLYLINE 212: Not a rectangle
# LWPOLYLINE 213: Not a rectangle
# LWPOLYLINE 214: Not a rectangle
# LWPOLYLINE 215: Not a rectangle
# LWPOLYLINE 216:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 30392.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 30392.000000000553)
#   Gradient: 0.20924100643393123
# LWPOLYLINE 217:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 29233.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 29233.000000000553)
#   Gradient: 0.22108309693124162
# LWPOLYLINE 218: Not a rectangle
# LWPOLYLINE 219: Not a rectangle
# LWPOLYLINE 220: Not a rectangle
# LWPOLYLINE 221: Not a rectangle
# LWPOLYLINE 222:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 29233.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 29233.000000000553)
#   Gradient: 0.20110989741609647
# LWPOLYLINE 223:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 28074.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 28074.000000000553)
#   Gradient: 0.21214444803208218
# LWPOLYLINE 224: Not a rectangle
# LWPOLYLINE 225: Not a rectangle
# LWPOLYLINE 226: Not a rectangle
# LWPOLYLINE 227: Not a rectangle
# LWPOLYLINE 228:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 28074.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 28074.000000000553)
#   Gradient: 0.1929787883982617
# LWPOLYLINE 229:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 26915.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 26915.000000000553)
#   Gradient: 0.20320579913292278
# LWPOLYLINE 230: Not a rectangle
# LWPOLYLINE 231: Not a rectangle
# LWPOLYLINE 232: Not a rectangle
# LWPOLYLINE 233: Not a rectangle
# LWPOLYLINE 234:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 26915.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 26915.000000000553)
#   Gradient: 0.18484767938042695
# LWPOLYLINE 235:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 25756.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 25756.000000000553)
#   Gradient: 0.19426715023376334
# LWPOLYLINE 236: Not a rectangle
# LWPOLYLINE 237: Not a rectangle
# LWPOLYLINE 238: Not a rectangle
# LWPOLYLINE 239: Not a rectangle
# LWPOLYLINE 240:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 25756.000000000553)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 25756.000000000553)
#   Gradient: 0.17671657036259217
# LWPOLYLINE 241:
#   Orientation: Horizontal
#   Center: (130826.55526387852, 48152.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582471
#   Cell center: (131409.00594002413, 48152.00000000035)
#   Gradient: 0.3669936219728252
# LWPOLYLINE 242:
#   Orientation: Horizontal
#   Center: (133166.34426380857, 48152.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045823983
#   Cell center: (133748.79493995418, 48152.00000000035)
#   Gradient: 0.36048848368951025
# LWPOLYLINE 243: Not a rectangle
# LWPOLYLINE 244: Not a rectangle
# LWPOLYLINE 245:
#   Orientation: Horizontal
#   Center: (141364.09411460886, 48152.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704581991
#   Cell center: (141946.54479075436, 48152.00000000035)
#   Gradient: 0.3394099428280734
# LWPOLYLINE 246: Not a rectangle
# LWPOLYLINE 247:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 69389.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 69389.00000000015)
#   Gradient: 0.5307814448127285
# LWPOLYLINE 248: Not a rectangle
# LWPOLYLINE 249: Not a rectangle
# LWPOLYLINE 250: Not a rectangle
# LWPOLYLINE 251: Not a rectangle
# LWPOLYLINE 252:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 69389.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 69389.00000000015)
#   Gradient: 0.4828293225413512
# LWPOLYLINE 253: Not a rectangle
# LWPOLYLINE 254: Not a rectangle
# LWPOLYLINE 255: Not a rectangle
# LWPOLYLINE 256: Not a rectangle
# LWPOLYLINE 257:
#   Orientation: Horizontal
#   Center: (141364.09411460886, 70548.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704581991
#   Cell center: (141946.54479075436, 70548.00000000015)
#   Gradient: 0.4991540865619687
# LWPOLYLINE 258:
#   Orientation: Horizontal
#   Center: (143703.8831145391, 70548.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045824856
#   Cell center: (144286.3337906847, 70548.00000000015)
#   Gradient: 0.49096043155918595
# LWPOLYLINE 259:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 68230.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 68230.00000000015)
#   Gradient: 0.521842795913569
# LWPOLYLINE 260: Not a rectangle
# LWPOLYLINE 261: Not a rectangle
# LWPOLYLINE 262: Not a rectangle
# LWPOLYLINE 263: Not a rectangle
# LWPOLYLINE 264:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 68230.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 68230.00000000015)
#   Gradient: 0.47469821352351643
# LWPOLYLINE 265:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 67071.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 67071.00000000015)
#   Gradient: 0.5129041470144096
# LWPOLYLINE 266: Not a rectangle
# LWPOLYLINE 267: Not a rectangle
# LWPOLYLINE 268: Not a rectangle
# LWPOLYLINE 269: Not a rectangle
# LWPOLYLINE 270:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 67071.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 67071.00000000015)
#   Gradient: 0.4665671045056816
# LWPOLYLINE 271:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 65537.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 65537.00000000035)
#   Gradient: 0.5010733554602166
# LWPOLYLINE 272: Not a rectangle
# LWPOLYLINE 273: Not a rectangle
# LWPOLYLINE 274: Not a rectangle
# LWPOLYLINE 275: Not a rectangle
# LWPOLYLINE 276:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 65537.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 65537.00000000035)
#   Gradient: 0.4558051362284102
# LWPOLYLINE 277:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 64378.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 64378.00000000035)
#   Gradient: 0.4921347065610571
# LWPOLYLINE 278: Not a rectangle
# LWPOLYLINE 279: Not a rectangle
# LWPOLYLINE 280: Not a rectangle
# LWPOLYLINE 281: Not a rectangle
# LWPOLYLINE 282:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 64378.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 64378.00000000035)
#   Gradient: 0.4476740272105754
# LWPOLYLINE 283:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 63219.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 63219.00000000035)
#   Gradient: 0.4831960576618977
# LWPOLYLINE 284: Not a rectangle
# LWPOLYLINE 285: Not a rectangle
# LWPOLYLINE 286: Not a rectangle
# LWPOLYLINE 287: Not a rectangle
# LWPOLYLINE 288:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 63219.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 63219.00000000035)
#   Gradient: 0.43954291819274066
# LWPOLYLINE 289:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 62060.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 62060.00000000035)
#   Gradient: 0.4742574087627383
# LWPOLYLINE 290: Not a rectangle
# LWPOLYLINE 291: Not a rectangle
# LWPOLYLINE 292: Not a rectangle
# LWPOLYLINE 293: Not a rectangle
# LWPOLYLINE 294:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 62060.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 62060.00000000035)
#   Gradient: 0.43141180917490585
# LWPOLYLINE 295:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 60901.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 60901.00000000035)
#   Gradient: 0.46531875986357885
# LWPOLYLINE 296: Not a rectangle
# LWPOLYLINE 297: Not a rectangle
# LWPOLYLINE 298: Not a rectangle
# LWPOLYLINE 299: Not a rectangle
# LWPOLYLINE 300:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 60901.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 60901.00000000035)
#   Gradient: 0.4232807001570711
# LWPOLYLINE 301:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 59742.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 59742.00000000035)
#   Gradient: 0.45638011096442016
# LWPOLYLINE 302: Not a rectangle
# LWPOLYLINE 303: Not a rectangle
# LWPOLYLINE 304: Not a rectangle
# LWPOLYLINE 305: Not a rectangle
# LWPOLYLINE 306:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 59742.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 59742.00000000035)
#   Gradient: 0.41514959113923694
# LWPOLYLINE 307:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 58583.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 58583.00000000035)
#   Gradient: 0.4474414620652607
# LWPOLYLINE 308: Not a rectangle
# LWPOLYLINE 309: Not a rectangle
# LWPOLYLINE 310: Not a rectangle
# LWPOLYLINE 311: Not a rectangle
# LWPOLYLINE 312:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 58583.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 58583.00000000035)
#   Gradient: 0.4070184821214022
# LWPOLYLINE 313:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 57424.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 57424.00000000035)
#   Gradient: 0.4385028131661013
# LWPOLYLINE 314: Not a rectangle
# LWPOLYLINE 315: Not a rectangle
# LWPOLYLINE 316: Not a rectangle
# LWPOLYLINE 317: Not a rectangle
# LWPOLYLINE 318:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 57424.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 57424.00000000035)
#   Gradient: 0.39888737310356737
# LWPOLYLINE 319:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 56265.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 56265.00000000035)
#   Gradient: 0.42956416426694183
# LWPOLYLINE 320: Not a rectangle
# LWPOLYLINE 321: Not a rectangle
# LWPOLYLINE 322: Not a rectangle
# LWPOLYLINE 323: Not a rectangle
# LWPOLYLINE 324:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 56265.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 56265.00000000035)
#   Gradient: 0.3907562640857326
# LWPOLYLINE 325:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 55106.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 55106.00000000035)
#   Gradient: 0.42062551536778175
# LWPOLYLINE 326: Not a rectangle
# LWPOLYLINE 327: Not a rectangle
# LWPOLYLINE 328: Not a rectangle
# LWPOLYLINE 329: Not a rectangle
# LWPOLYLINE 330:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 55106.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 55106.00000000035)
#   Gradient: 0.3826251550678973
# LWPOLYLINE 331:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 53947.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 53947.00000000035)
#   Gradient: 0.4116868664686223
# LWPOLYLINE 332: Not a rectangle
# LWPOLYLINE 333: Not a rectangle
# LWPOLYLINE 334: Not a rectangle
# LWPOLYLINE 335: Not a rectangle
# LWPOLYLINE 336:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 53947.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 53947.00000000035)
#   Gradient: 0.37449404605006253
# LWPOLYLINE 337:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 52788.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 52788.00000000035)
#   Gradient: 0.4027482175694629
# LWPOLYLINE 338: Not a rectangle
# LWPOLYLINE 339: Not a rectangle
# LWPOLYLINE 340: Not a rectangle
# LWPOLYLINE 341: Not a rectangle
# LWPOLYLINE 342:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 52788.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 52788.00000000035)
#   Gradient: 0.3663629370322278
# LWPOLYLINE 343:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 51629.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 51629.00000000035)
#   Gradient: 0.3938095686703035
# LWPOLYLINE 344: Not a rectangle
# LWPOLYLINE 345: Not a rectangle
# LWPOLYLINE 346: Not a rectangle
# LWPOLYLINE 347: Not a rectangle
# LWPOLYLINE 348:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 51629.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 51629.00000000035)
#   Gradient: 0.358231828014393
# LWPOLYLINE 349:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 50470.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 50470.00000000035)
#   Gradient: 0.384870919771144
# LWPOLYLINE 350: Not a rectangle
# LWPOLYLINE 351: Not a rectangle
# LWPOLYLINE 352: Not a rectangle
# LWPOLYLINE 353: Not a rectangle
# LWPOLYLINE 354:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 50470.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 50470.00000000035)
#   Gradient: 0.35010071899655826
# LWPOLYLINE 355:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 49311.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 49311.00000000035)
#   Gradient: 0.3759322708719846
# LWPOLYLINE 356: Not a rectangle
# LWPOLYLINE 357: Not a rectangle
# LWPOLYLINE 358: Not a rectangle
# LWPOLYLINE 359: Not a rectangle
# LWPOLYLINE 360:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 49311.00000000035)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 49311.00000000035)
#   Gradient: 0.3419696099787235
# LWPOLYLINE 361:
#   Orientation: Horizontal
#   Center: (130826.55526387852, 71707.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582471
#   Cell center: (131409.00594002413, 71707.00000000015)
#   Gradient: 0.5486587426110464
# LWPOLYLINE 362:
#   Orientation: Horizontal
#   Center: (133166.34426380857, 71707.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045823983
#   Cell center: (133748.79493995418, 71707.00000000015)
#   Gradient: 0.5389335027775901
# LWPOLYLINE 363: Not a rectangle
# LWPOLYLINE 364: Not a rectangle
# LWPOLYLINE 365:
#   Orientation: Horizontal
#   Center: (141364.09411460886, 71707.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704581991
#   Cell center: (141946.54479075436, 71707.00000000015)
#   Gradient: 0.5074208959291586
# LWPOLYLINE 366: Not a rectangle
# LWPOLYLINE 367:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 93344.00000000003)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 93344.00000000003)
#   Gradient: 0.7155315176163195
# LWPOLYLINE 368: Not a rectangle
# LWPOLYLINE 369: Not a rectangle
# LWPOLYLINE 370: Not a rectangle
# LWPOLYLINE 371: Not a rectangle
# LWPOLYLINE 372:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 93344.00000000003)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 93344.00000000003)
#   Gradient: 0.6508886120342158
# LWPOLYLINE 373: Not a rectangle
# LWPOLYLINE 374: Not a rectangle
# LWPOLYLINE 375: Not a rectangle
# LWPOLYLINE 376: Not a rectangle
# LWPOLYLINE 377:
#   Orientation: Horizontal
#   Center: (141364.09411460906, 94503.00000000003)
#   Average Height: 1134.0
#   Average Width: 2329.802704581991
#   Cell center: (141946.54479075456, 94503.00000000003)
#   Gradient: 0.6700181231374936
# LWPOLYLINE 378:
#   Orientation: Horizontal
#   Center: (143703.88311453932, 94503.00000000003)
#   Average Height: 1134.0
#   Average Width: 2329.8027045824856
#   Cell center: (144286.33379068493, 94503.00000000003)
#   Gradient: 0.6590197210520505
# LWPOLYLINE 379:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 92185.00000000003)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 92185.00000000003)
#   Gradient: 0.7065928687171601
# LWPOLYLINE 380: Not a rectangle
# LWPOLYLINE 381: Not a rectangle
# LWPOLYLINE 382: Not a rectangle
# LWPOLYLINE 383: Not a rectangle
# LWPOLYLINE 384:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 92185.00000000003)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 92185.00000000003)
#   Gradient: 0.6427575030163809
# LWPOLYLINE 385:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 91026.00000000003)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 91026.00000000003)
#   Gradient: 0.6976542198180007
# LWPOLYLINE 386: Not a rectangle
# LWPOLYLINE 387: Not a rectangle
# LWPOLYLINE 388: Not a rectangle
# LWPOLYLINE 389: Not a rectangle
# LWPOLYLINE 390:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 91026.00000000003)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 91026.00000000003)
#   Gradient: 0.6346263939985461
# LWPOLYLINE 391:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 89092.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 89092.00000000015)
#   Gradient: 0.6827384760984379
# LWPOLYLINE 392: Not a rectangle
# LWPOLYLINE 393: Not a rectangle
# LWPOLYLINE 394: Not a rectangle
# LWPOLYLINE 395: Not a rectangle
# LWPOLYLINE 396:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 89092.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 89092.00000000015)
#   Gradient: 0.6210581758445415
# LWPOLYLINE 397:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 87933.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 87933.00000000015)
#   Gradient: 0.6737998271992784
# LWPOLYLINE 398: Not a rectangle
# LWPOLYLINE 399: Not a rectangle
# LWPOLYLINE 400: Not a rectangle
# LWPOLYLINE 401: Not a rectangle
# LWPOLYLINE 402:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 87933.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 87933.00000000015)
#   Gradient: 0.6129270668267067
# LWPOLYLINE 403:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 86774.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 86774.00000000015)
#   Gradient: 0.6648611783001189
# LWPOLYLINE 404: Not a rectangle
# LWPOLYLINE 405: Not a rectangle
# LWPOLYLINE 406: Not a rectangle
# LWPOLYLINE 407: Not a rectangle
# LWPOLYLINE 408:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 86774.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 86774.00000000015)
#   Gradient: 0.604795957808872
# LWPOLYLINE 409:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 85615.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 85615.00000000015)
#   Gradient: 0.6559225294009595
# LWPOLYLINE 410: Not a rectangle
# LWPOLYLINE 411: Not a rectangle
# LWPOLYLINE 412: Not a rectangle
# LWPOLYLINE 413: Not a rectangle
# LWPOLYLINE 414:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 85615.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 85615.00000000015)
#   Gradient: 0.5966648487910372
# LWPOLYLINE 415:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 84456.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 84456.00000000015)
#   Gradient: 0.6469838805018001
# LWPOLYLINE 416: Not a rectangle
# LWPOLYLINE 417: Not a rectangle
# LWPOLYLINE 418: Not a rectangle
# LWPOLYLINE 419: Not a rectangle
# LWPOLYLINE 420:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 84456.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 84456.00000000015)
#   Gradient: 0.5885337397732024
# LWPOLYLINE 421:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 83297.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 83297.00000000015)
#   Gradient: 0.6380452316026417
# LWPOLYLINE 422: Not a rectangle
# LWPOLYLINE 423: Not a rectangle
# LWPOLYLINE 424: Not a rectangle
# LWPOLYLINE 425: Not a rectangle
# LWPOLYLINE 426:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 83297.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 83297.00000000015)
#   Gradient: 0.5804026307553685
# LWPOLYLINE 427:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 82138.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 82138.00000000015)
#   Gradient: 0.6291065827034823
# LWPOLYLINE 428: Not a rectangle
# LWPOLYLINE 429: Not a rectangle
# LWPOLYLINE 430: Not a rectangle
# LWPOLYLINE 431: Not a rectangle
# LWPOLYLINE 432:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 82138.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 82138.00000000015)
#   Gradient: 0.5722715217375337
# LWPOLYLINE 433:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 80979.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 80979.00000000015)
#   Gradient: 0.6201679338043228
# LWPOLYLINE 434: Not a rectangle
# LWPOLYLINE 435: Not a rectangle
# LWPOLYLINE 436: Not a rectangle
# LWPOLYLINE 437: Not a rectangle
# LWPOLYLINE 438:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 80979.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 80979.00000000015)
#   Gradient: 0.564140412719699
# LWPOLYLINE 439:
#   Orientation: Horizontal
#   Center: (130826.5552638784, 79820.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002407, 79820.00000000015)
#   Gradient: 0.6112292849051634
# LWPOLYLINE 440: Not a rectangle
# LWPOLYLINE 441: Not a rectangle
# LWPOLYLINE 442: Not a rectangle
# LWPOLYLINE 443: Not a rectangle
# LWPOLYLINE 444:
#   Orientation: Horizontal
#   Center: (143703.88311453897, 79820.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.8027045821946
#   Cell center: (144286.33379068453, 79820.00000000015)
#   Gradient: 0.5560093037018642
# LWPOLYLINE 445:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 78661.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 78661.00000000015)
#   Gradient: 0.602290636006003
# LWPOLYLINE 446: Not a rectangle
# LWPOLYLINE 447: Not a rectangle
# LWPOLYLINE 448: Not a rectangle
# LWPOLYLINE 449: Not a rectangle
# LWPOLYLINE 450:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 78661.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 78661.00000000015)
#   Gradient: 0.5478781946840287
# LWPOLYLINE 451:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 77502.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 77502.00000000015)
#   Gradient: 0.5933519871068436
# LWPOLYLINE 452: Not a rectangle
# LWPOLYLINE 453: Not a rectangle
# LWPOLYLINE 454: Not a rectangle
# LWPOLYLINE 455: Not a rectangle
# LWPOLYLINE 456:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 77502.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 77502.00000000015)
#   Gradient: 0.5397470856661938
# LWPOLYLINE 457:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 76343.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 76343.00000000015)
#   Gradient: 0.5844133382076842
# LWPOLYLINE 458: Not a rectangle
# LWPOLYLINE 459: Not a rectangle
# LWPOLYLINE 460: Not a rectangle
# LWPOLYLINE 461: Not a rectangle
# LWPOLYLINE 462:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 76343.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 76343.00000000015)
#   Gradient: 0.531615976648359
# LWPOLYLINE 463:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 75184.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 75184.00000000015)
#   Gradient: 0.5754746893085247
# LWPOLYLINE 464: Not a rectangle
# LWPOLYLINE 465: Not a rectangle
# LWPOLYLINE 466: Not a rectangle
# LWPOLYLINE 467: Not a rectangle
# LWPOLYLINE 468:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 75184.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
#   Cell center: (144286.33379068476, 75184.00000000015)
#   Gradient: 0.5234848676305243
# LWPOLYLINE 469:
#   Orientation: Horizontal
#   Center: (130826.5552638786, 74025.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582675
#   Cell center: (131409.00594002428, 74025.00000000015)
#   Gradient: 0.5665360404093653
# LWPOLYLINE 470: Not a rectangle
# LWPOLYLINE 471: Not a rectangle
# LWPOLYLINE 472: Not a rectangle
# LWPOLYLINE 473: Not a rectangle
# LWPOLYLINE 474:
#   Orientation: Horizontal
#   Center: (143703.8831145392, 74025.00000000015)
#   Average Height: 1134.0
#   Average Width: 2329.802704582282
# ...
# LWPOLYLINE 2872: Not a rectangle
# LWPOLYLINE 2873: Not a rectangle
# LWPOLYLINE 2874: Not a rectangle
# LWPOLYLINE 2875: Not a rectangle
# LWPOLYLINE 2876: Not a rectangle
# LWPOLYLINE 2877: Not a rectangle
# LWPOLYLINE 2878: Not a rectangle
# LWPOLYLINE 2879: Not a rectangle
# LWPOLYLINE 2880: Not a rectangle
# LWPOLYLINE 2881: Not a rectangle
# LWPOLYLINE 2882: Not a rectangle
# LWPOLYLINE 2883: Not a rectangle
# LWPOLYLINE 2884: Not a rectangle
# LWPOLYLINE 2885: Not a rectangle
# LWPOLYLINE 2886: Not a rectangle
# LWPOLYLINE 2887: Not a rectangle
# LWPOLYLINE 2888: Not a rectangle
# LWPOLYLINE 2889: Not a rectangle
# LWPOLYLINE 2890: Not a rectangle
# LWPOLYLINE 2891: Not a rectangle
# LWPOLYLINE 2892: Not a rectangle
# LWPOLYLINE 2893: Not a rectangle
# LWPOLYLINE 2894: Not a rectangle
# LWPOLYLINE 2895: Not a rectangle
# LWPOLYLINE 2896: Not a rectangle
# LWPOLYLINE 2897: Not a rectangle
# LWPOLYLINE 2898: Not a rectangle
# LWPOLYLINE 2899: Not a rectangle
# LWPOLYLINE 2900: Not a rectangle
# LWPOLYLINE 2901: Not a rectangle
# LWPOLYLINE 2902: Not a rectangle
# LWPOLYLINE 2903: Not a rectangle
# LWPOLYLINE 2904: Not a rectangle
# LWPOLYLINE 2905: Not a rectangle
# LWPOLYLINE 2906: Not a rectangle
# LWPOLYLINE 2907: Not a rectangle
# LWPOLYLINE 2908: Not a rectangle
# LWPOLYLINE 2909: Not a rectangle
# LWPOLYLINE 2910: Not a rectangle
# LWPOLYLINE 2911: Not a rectangle
# LWPOLYLINE 2912: Not a rectangle
# LWPOLYLINE 2913: Not a rectangle
# LWPOLYLINE 2914: Not a rectangle
# LWPOLYLINE 2915: Not a rectangle
# LWPOLYLINE 2916: Not a rectangle
# LWPOLYLINE 2917: Not a rectangle
# LWPOLYLINE 2918: Not a rectangle
# LWPOLYLINE 2919: Not a rectangle
# LWPOLYLINE 2920: Not a rectangle
# LWPOLYLINE 2921: Not a rectangle
# LWPOLYLINE 2922: Not a rectangle
# LWPOLYLINE 2923: Not a rectangle
# LWPOLYLINE 2924: Not a rectangle
# LWPOLYLINE 2925: Not a rectangle
# LWPOLYLINE 2926: Not a rectangle
# LWPOLYLINE 2927: Not a rectangle
# LWPOLYLINE 2928: Not a rectangle
# LWPOLYLINE 2929: Not a rectangle
# LWPOLYLINE 2930: Not a rectangle
# LWPOLYLINE 2931: Not a rectangle
# LWPOLYLINE 2932: Not a rectangle
# LWPOLYLINE 2933: Not a rectangle
# LWPOLYLINE 2934: Not a rectangle
# LWPOLYLINE 2935: Not a rectangle
# LWPOLYLINE 2936: Not a rectangle
# LWPOLYLINE 2937: Not a rectangle
# LWPOLYLINE 2938: Not a rectangle
# LWPOLYLINE 2939: Not a rectangle
# LWPOLYLINE 2940: Not a rectangle
# LWPOLYLINE 2941: Not a rectangle
# LWPOLYLINE 2942: Not a rectangle
# LWPOLYLINE 2943: Not a rectangle
# LWPOLYLINE 2944: Not a rectangle
# LWPOLYLINE 2945: Not a rectangle
# LWPOLYLINE 2946: Not a rectangle
# LWPOLYLINE 2947: Not a rectangle
# LWPOLYLINE 2948: Not a rectangle
# LWPOLYLINE 2949: Not a rectangle
# LWPOLYLINE 2950: Not a rectangle
# LWPOLYLINE 2951: Not a rectangle
# LWPOLYLINE 2952: Not a rectangle
# LWPOLYLINE 2953: Not a rectangle
# LWPOLYLINE 2954: Not a rectangle
# LWPOLYLINE 2955: Not a rectangle
# LWPOLYLINE 2956: Not a rectangle
# LWPOLYLINE 2957: Not a rectangle
# LWPOLYLINE 2958: Not a rectangle
# LWPOLYLINE 2959: Not a rectangle
# LWPOLYLINE 2960: Not a rectangle
# LWPOLYLINE 2961: Not a rectangle
# LWPOLYLINE 2962: Not a rectangle
# LWPOLYLINE 2963: Not a rectangle
# LWPOLYLINE 2964: Not a rectangle
# LWPOLYLINE 2965: Not a rectangle
# LWPOLYLINE 2966: Not a rectangle
# LWPOLYLINE 2967: Not a rectangle
# LWPOLYLINE 2968: Not a rectangle
# LWPOLYLINE 2969: Not a rectangle
# LWPOLYLINE 2970: Not a rectangle
# LWPOLYLINE 2971: Not a rectangle
# LWPOLYLINE 2972: Not a rectangle
# LWPOLYLINE 2973: Not a rectangle
# LWPOLYLINE 2974: Not a rectangle
# LWPOLYLINE 2975: Not a rectangle
# LWPOLYLINE 2976: Not a rectangle
# LWPOLYLINE 2977: Not a rectangle
# LWPOLYLINE 2978: Not a rectangle
# LWPOLYLINE 2979: Not a rectangle
# LWPOLYLINE 2980: Not a rectangle
# LWPOLYLINE 2981: Not a rectangle
# LWPOLYLINE 2982: Not a rectangle
# LWPOLYLINE 2983: Not a rectangle
# LWPOLYLINE 2984: Not a rectangle
# LWPOLYLINE 2985: Not a rectangle
# LWPOLYLINE 2986: Not a rectangle
# LWPOLYLINE 2987: Not a rectangle
# LWPOLYLINE 2988: Not a rectangle
# LWPOLYLINE 2989: Not a rectangle
# LWPOLYLINE 2990: Not a rectangle
# LWPOLYLINE 2991: Not a rectangle
# LWPOLYLINE 2992: Not a rectangle
# LWPOLYLINE 2993: Not a rectangle
# LWPOLYLINE 2994: Not a rectangle
# LWPOLYLINE 2995: Not a rectangle
# LWPOLYLINE 2996: Not a rectangle
# LWPOLYLINE 2997: Not a rectangle
# LWPOLYLINE 2998: Not a rectangle
# LWPOLYLINE 2999: Not a rectangle
# LWPOLYLINE 3000: Not a rectangle
# LWPOLYLINE 3001: Not a rectangle
# LWPOLYLINE 3002: Not a rectangle
# LWPOLYLINE 3003: Not a rectangle
# LWPOLYLINE 3004: Not a rectangle
# LWPOLYLINE 3005: Not a rectangle
# LWPOLYLINE 3006: Not a rectangle
# LWPOLYLINE 3007: Not a rectangle
# LWPOLYLINE 3008: Not a rectangle
# LWPOLYLINE 3009: Not a rectangle
# LWPOLYLINE 3010: Not a rectangle
# LWPOLYLINE 3011: Not a rectangle
# LWPOLYLINE 3012: Not a rectangle
# LWPOLYLINE 3013: Not a rectangle
# LWPOLYLINE 3014: Not a rectangle
# LWPOLYLINE 3015: Not a rectangle
# LWPOLYLINE 3016: Not a rectangle
# LWPOLYLINE 3017: Not a rectangle
# LWPOLYLINE 3018: Not a rectangle
# LWPOLYLINE 3019: Not a rectangle
# LWPOLYLINE 3020: Not a rectangle
# LWPOLYLINE 3021: Not a rectangle
# LWPOLYLINE 3022: Not a rectangle
# LWPOLYLINE 3023: Not a rectangle
# LWPOLYLINE 3024: Not a rectangle
# LWPOLYLINE 3025: Not a rectangle
# LWPOLYLINE 3026: Not a rectangle
# LWPOLYLINE 3027: Not a rectangle
# LWPOLYLINE 3028: Not a rectangle
# LWPOLYLINE 3029: Not a rectangle
# LWPOLYLINE 3030: Not a rectangle
# LWPOLYLINE 3031: Not a rectangle
# LWPOLYLINE 3032: Not a rectangle
# LWPOLYLINE 3033: Not a rectangle
# LWPOLYLINE 3034: Not a rectangle
# LWPOLYLINE 3035: Not a rectangle
# LWPOLYLINE 3036: Not a rectangle
# LWPOLYLINE 3037: Not a rectangle
# LWPOLYLINE 3038: Not a rectangle
# LWPOLYLINE 3039: Not a rectangle
# LWPOLYLINE 3040: Not a rectangle
# LWPOLYLINE 3041: Not a rectangle
# LWPOLYLINE 3042: Not a rectangle
# LWPOLYLINE 3043: Not a rectangle
# LWPOLYLINE 3044: Not a rectangle
# LWPOLYLINE 3045: Not a rectangle
# LWPOLYLINE 3046: Not a rectangle
# LWPOLYLINE 3047: Not a rectangle
# LWPOLYLINE 3048: Not a rectangle
# LWPOLYLINE 3049: Not a rectangle
# LWPOLYLINE 3050: Not a rectangle
# LWPOLYLINE 3051: Not a rectangle
# LWPOLYLINE 3052: Not a rectangle
# LWPOLYLINE 3053: Not a rectangle
# LWPOLYLINE 3054: Not a rectangle
# LWPOLYLINE 3055: Not a rectangle
# LWPOLYLINE 3056: Not a rectangle
# LWPOLYLINE 3057: Not a rectangle
# LWPOLYLINE 3058: Not a rectangle
# LWPOLYLINE 3059: Not a rectangle
# LWPOLYLINE 3060: Not a rectangle
# LWPOLYLINE 3061: Not a rectangle
# LWPOLYLINE 3062: Not a rectangle
# LWPOLYLINE 3063: Not a rectangle
# LWPOLYLINE 3064: Not a rectangle
# LWPOLYLINE 3065: Not a rectangle
# LWPOLYLINE 3066: Not a rectangle
# LWPOLYLINE 3067: Not a rectangle
# LWPOLYLINE 3068: Not a rectangle
# LWPOLYLINE 3069: Not a rectangle
# LWPOLYLINE 3070: Not a rectangle
# LWPOLYLINE 3071: Not a rectangle
# LWPOLYLINE 3072: Not a rectangle
# LWPOLYLINE 3073: Not a rectangle
# LWPOLYLINE 3074: Not a rectangle
# LWPOLYLINE 3075: Not a rectangle
# LWPOLYLINE 3076: Not a rectangle
# LWPOLYLINE 3077: Not a rectangle
# LWPOLYLINE 3078: Not a rectangle
# LWPOLYLINE 3079: Not a rectangle
# LWPOLYLINE 3080: Not a rectangle
# LWPOLYLINE 3081: Not a rectangle
# LWPOLYLINE 3082: Not a rectangle
# LWPOLYLINE 3083: Not a rectangle
# LWPOLYLINE 3084: Not a rectangle
# LWPOLYLINE 3085: Not a rectangle
# LWPOLYLINE 3086: Not a rectangle
# LWPOLYLINE 3087: Not a rectangle
# LWPOLYLINE 3088: Not a rectangle
# LWPOLYLINE 3089: Not a rectangle
# LWPOLYLINE 3090: Not a rectangle
# LWPOLYLINE 3091: Not a rectangle
# LWPOLYLINE 3092: Not a rectangle
# LWPOLYLINE 3093: Not a rectangle
# LWPOLYLINE 3094: Not a rectangle
# LWPOLYLINE 3095: Not a rectangle
# LWPOLYLINE 3096: Not a rectangle
# LWPOLYLINE 3097: Not a rectangle
# LWPOLYLINE 3098: Not a rectangle
# LWPOLYLINE 3099: Not a rectangle
# LWPOLYLINE 3100: Not a rectangle
# LWPOLYLINE 3101: Not a rectangle
# LWPOLYLINE 3102: Not a rectangle
# LWPOLYLINE 3103: Not a rectangle
# LWPOLYLINE 3104: Not a rectangle
# LWPOLYLINE 3105: Not a rectangle
# LWPOLYLINE 3106: Not a rectangle
# LWPOLYLINE 3107: Not a rectangle
# LWPOLYLINE 3108: Not a rectangle
# LWPOLYLINE 3109: Not a rectangle
# LWPOLYLINE 3110: Not a rectangle
# LWPOLYLINE 3111: Not a rectangle
# LWPOLYLINE 3112: Not a rectangle
# LWPOLYLINE 3113: Not a rectangle
# LWPOLYLINE 3114: Not a rectangle
# LWPOLYLINE 3115: Not a rectangle
# LWPOLYLINE 3116: Not a rectangle
# LWPOLYLINE 3117: Not a rectangle
# LWPOLYLINE 3118: Not a rectangle
# LWPOLYLINE 3119: Not a rectangle
# LWPOLYLINE 3120: Not a rectangle
# LWPOLYLINE 3121: Not a rectangle
# LWPOLYLINE 3122: Not a rectangle
# LWPOLYLINE 3123: Not a rectangle
# LWPOLYLINE 3124: Not a rectangle
# LWPOLYLINE 3125: Not a rectangle
# LWPOLYLINE 3126: Not a rectangle
# LWPOLYLINE 3127: Not a rectangle
# LWPOLYLINE 3128: Not a rectangle
# LWPOLYLINE 3129: Not a rectangle
# LWPOLYLINE 3130: Not a rectangle
# LWPOLYLINE 3131: Not a rectangle
# LWPOLYLINE 3132: Not a rectangle
# LWPOLYLINE 3133: Not a rectangle
# LWPOLYLINE 3134: Not a rectangle
# LWPOLYLINE 3135: Not a rectangle
# LWPOLYLINE 3136: Not a rectangle
# LWPOLYLINE 3137: Not a rectangle
# LWPOLYLINE 3138: Not a rectangle
# LWPOLYLINE 3139: Not a rectangle
# LWPOLYLINE 3140: Not a rectangle
# LWPOLYLINE 3141: Not a rectangle
# LWPOLYLINE 3142: Not a rectangle
# LWPOLYLINE 3143: Not a rectangle
# LWPOLYLINE 3144: Not a rectangle
# LWPOLYLINE 3145: Not a rectangle
# LWPOLYLINE 3146: Not a rectangle
# LWPOLYLINE 3147: Not a rectangle
# LWPOLYLINE 3148: Not a rectangle
# LWPOLYLINE 3149: Not a rectangle
# LWPOLYLINE 3150: Not a rectangle
# LWPOLYLINE 3151: Not a rectangle
# LWPOLYLINE 3152: Not a rectangle
# LWPOLYLINE 3153: Not a rectangle
# LWPOLYLINE 3154: Not a rectangle
# LWPOLYLINE 3155: Not a rectangle
# LWPOLYLINE 3156: Not a rectangle
# LWPOLYLINE 3157: Not a rectangle
# LWPOLYLINE 3158: Not a rectangle
# LWPOLYLINE 3159: Not a rectangle
# LWPOLYLINE 3160: Not a rectangle
# LWPOLYLINE 3161: Not a rectangle
# LWPOLYLINE 3162: Not a rectangle
# LWPOLYLINE 3163: Not a rectangle
# LWPOLYLINE 3164: Not a rectangle
# LWPOLYLINE 3165: Not a rectangle
# LWPOLYLINE 3166: Not a rectangle
# LWPOLYLINE 3167: Not a rectangle
# LWPOLYLINE 3168: Not a rectangle
# LWPOLYLINE 3169: Not a rectangle
# LWPOLYLINE 3170: Not a rectangle
# LWPOLYLINE 3171: Not a rectangle
# LWPOLYLINE 3172: Not a rectangle
# LWPOLYLINE 3173: Not a rectangle
# LWPOLYLINE 3174: Not a rectangle
# LWPOLYLINE 3175: Not a rectangle
# LWPOLYLINE 3176: Not a rectangle
# LWPOLYLINE 3177: Not a rectangle
# LWPOLYLINE 3178: Not a rectangle
# LWPOLYLINE 3179: Not a rectangle
# LWPOLYLINE 3180: Not a rectangle
# LWPOLYLINE 3181: Not a rectangle
# LWPOLYLINE 3182: Not a rectangle
# LWPOLYLINE 3183: Not a rectangle
# LWPOLYLINE 3184: Not a rectangle
# LWPOLYLINE 3185: Not a rectangle
# LWPOLYLINE 3186: Not a rectangle
# LWPOLYLINE 3187: Not a rectangle
# LWPOLYLINE 3188: Not a rectangle
# LWPOLYLINE 3189: Not a rectangle
# LWPOLYLINE 3190: Not a rectangle
# LWPOLYLINE 3191: Not a rectangle
# LWPOLYLINE 3192: Not a rectangle
# LWPOLYLINE 3193: Not a rectangle
# LWPOLYLINE 3194: Not a rectangle
# LWPOLYLINE 3195: Not a rectangle
# LWPOLYLINE 3196: Not a rectangle
# LWPOLYLINE 3197: Not a rectangle
# LWPOLYLINE 3198: Not a rectangle
# LWPOLYLINE 3199: Not a rectangle
# LWPOLYLINE 3200: Not a rectangle
# LWPOLYLINE 3201: Not a rectangle
# LWPOLYLINE 3202: Not a rectangle
# LWPOLYLINE 3203: Not a rectangle
# LWPOLYLINE 3204: Not a rectangle
# LWPOLYLINE 3205: Not a rectangle
# LWPOLYLINE 3206: Not a rectangle
# LWPOLYLINE 3207: Not a rectangle
# LWPOLYLINE 3208: Not a rectangle
# LWPOLYLINE 3209: Not a rectangle
# LWPOLYLINE 3210: Not a rectangle
# LWPOLYLINE 3211: Not a rectangle
# LWPOLYLINE 3212: Not a rectangle
# LWPOLYLINE 3213: Not a rectangle
# LWPOLYLINE 3214: Not a rectangle
# LWPOLYLINE 3215: Not a rectangle
# LWPOLYLINE 3216: Not a rectangle
# LWPOLYLINE 3217: Not a rectangle
# LWPOLYLINE 3218: Not a rectangle
# LWPOLYLINE 3219: Not a rectangle
# LWPOLYLINE 3220: Not a rectangle
# LWPOLYLINE 3221: Not a rectangle
# LWPOLYLINE 3222: Not a rectangle
# LWPOLYLINE 3223: Not a rectangle
# LWPOLYLINE 3224: Not a rectangle
# LWPOLYLINE 3225: Not a rectangle
# LWPOLYLINE 3226: Not a rectangle
# LWPOLYLINE 3227: Not a rectangle
# LWPOLYLINE 3228: Not a rectangle
# LWPOLYLINE 3229: Not a rectangle
# LWPOLYLINE 3230: Not a rectangle
# LWPOLYLINE 3231: Not a rectangle
# LWPOLYLINE 3232: Not a rectangle
# LWPOLYLINE 3233: Not a rectangle
# LWPOLYLINE 3234: Not a rectangle
# LWPOLYLINE 3235: Not a rectangle
# LWPOLYLINE 3236: Not a rectangle
# LWPOLYLINE 3237: Not a rectangle
# LWPOLYLINE 3238: Not a rectangle
# LWPOLYLINE 3239: Not a rectangle
# LWPOLYLINE 3240: Not a rectangle
# LWPOLYLINE 3241: Not a rectangle
# LWPOLYLINE 3242: Not a rectangle
# LWPOLYLINE 3243: Not a rectangle
# LWPOLYLINE 3244: Not a rectangle
# LWPOLYLINE 3245: Not a rectangle
# LWPOLYLINE 3246: Not a rectangle
# LWPOLYLINE 3247: Not a rectangle
# LWPOLYLINE 3248: Not a rectangle
# LWPOLYLINE 3249: Not a rectangle
# LWPOLYLINE 3250: Not a rectangle
# LWPOLYLINE 3251: Not a rectangle
# LWPOLYLINE 3252: Not a rectangle
# LWPOLYLINE 3253: Not a rectangle
# LWPOLYLINE 3254: Not a rectangle
# LWPOLYLINE 3255: Not a rectangle
# LWPOLYLINE 3256: Not a rectangle
# LWPOLYLINE 3257: Not a rectangle
# LWPOLYLINE 3258: Not a rectangle
# LWPOLYLINE 3259: Not a rectangle
# LWPOLYLINE 3260: Not a rectangle
# LWPOLYLINE 3261: Not a rectangle
# LWPOLYLINE 3262: Not a rectangle
# LWPOLYLINE 3263: Not a rectangle
# LWPOLYLINE 3264: Not a rectangle
# LWPOLYLINE 3265: Not a rectangle
# LWPOLYLINE 3266: Not a rectangle
# LWPOLYLINE 3267: Not a rectangle
# LWPOLYLINE 3268: Not a rectangle
# LWPOLYLINE 3269: Not a rectangle
# LWPOLYLINE 3270: Not a rectangle
# LWPOLYLINE 3271: Not a rectangle
# LWPOLYLINE 3272: Not a rectangle
# LWPOLYLINE 3273: Not a rectangle
# LWPOLYLINE 3274: Not a rectangle
# LWPOLYLINE 3275: Not a rectangle
# LWPOLYLINE 3276: Not a rectangle
# LWPOLYLINE 3277: Not a rectangle
# LWPOLYLINE 3278: Not a rectangle
# LWPOLYLINE 3279: Not a rectangle
# LWPOLYLINE 3280: Not a rectangle
# LWPOLYLINE 3281: Not a rectangle
# LWPOLYLINE 3282: Not a rectangle
# LWPOLYLINE 3283: Not a rectangle
# LWPOLYLINE 3284: Not a rectangle
# LWPOLYLINE 3285: Not a rectangle
# LWPOLYLINE 3286: Not a rectangle
# LWPOLYLINE 3287: Not a rectangle
# LWPOLYLINE 3288: Not a rectangle
# LWPOLYLINE 3289: Not a rectangle
# LWPOLYLINE 3290: Not a rectangle
# LWPOLYLINE 3291: Not a rectangle
# LWPOLYLINE 3292: Not a rectangle
# LWPOLYLINE 3293: Not a rectangle
# LWPOLYLINE 3294: Not a rectangle
# LWPOLYLINE 3295: Not a rectangle
# LWPOLYLINE 3296: Not a rectangle
# LWPOLYLINE 3297: Not a rectangle
# LWPOLYLINE 3298: Not a rectangle
# LWPOLYLINE 3299: Not a rectangle
# LWPOLYLINE 3300: Not a rectangle
# LWPOLYLINE 3301: Not a rectangle
# LWPOLYLINE 3302: Not a rectangle
# LWPOLYLINE 3303: Not a rectangle
# LWPOLYLINE 3304: Not a rectangle
# LWPOLYLINE 3305: Not a rectangle
# LWPOLYLINE 3306: Not a rectangle
# LWPOLYLINE 3307: Not a rectangle
# LWPOLYLINE 3308: Not a rectangle
# LWPOLYLINE 3309: Not a rectangle
# LWPOLYLINE 3310: Not a rectangle
# LWPOLYLINE 3311: Not a rectangle
# LWPOLYLINE 3312: Not a rectangle
# LWPOLYLINE 3313: Not a rectangle
# LWPOLYLINE 3314: Not a rectangle
# LWPOLYLINE 3315: Not a rectangle
# LWPOLYLINE 3316: Not a rectangle
# LWPOLYLINE 3317: Not a rectangle
# LWPOLYLINE 3318: Not a rectangle
# LWPOLYLINE 3319: Not a rectangle
# LWPOLYLINE 3320: Not a rectangle
# LWPOLYLINE 3321: Not a rectangle
# LWPOLYLINE 3322: Not a rectangle
# LWPOLYLINE 3323: Not a rectangle
# LWPOLYLINE 3324: Not a rectangle
# LWPOLYLINE 3325: Not a rectangle
# LWPOLYLINE 3326: Not a rectangle
# LWPOLYLINE 3327: Not a rectangle
# LWPOLYLINE 3328: Not a rectangle
# LWPOLYLINE 3329: Not a rectangle
# LWPOLYLINE 3330: Not a rectangle
# LWPOLYLINE 3331: Not a rectangle
# LWPOLYLINE 3332: Not a rectangle
# LWPOLYLINE 3333: Not a rectangle
# LWPOLYLINE 3334: Not a rectangle
# LWPOLYLINE 3335: Not a rectangle
# LWPOLYLINE 3336: Not a rectangle
# LWPOLYLINE 3337: Not a rectangle
# LWPOLYLINE 3338: Not a rectangle
# LWPOLYLINE 3339: Not a rectangle
# LWPOLYLINE 3340: Not a rectangle
# LWPOLYLINE 3341: Not a rectangle
# LWPOLYLINE 3342: Not a rectangle
# LWPOLYLINE 3343: Not a rectangle
# LWPOLYLINE 3344: Not a rectangle
# LWPOLYLINE 3345: Not a rectangle
# LWPOLYLINE 3346: Not a rectangle
# LWPOLYLINE 3347: Not a rectangle
# LWPOLYLINE 3348: Not a rectangle
# LWPOLYLINE 3349: Not a rectangle
# LWPOLYLINE 3350: Not a rectangle
# LWPOLYLINE 3351: Not a rectangle
# LWPOLYLINE 3352: Not a rectangle
# LWPOLYLINE 3353: Not a rectangle
# LWPOLYLINE 3354: Not a rectangle
# LWPOLYLINE 3355: Not a rectangle

# %%
def move_polylines_to_origin(lwpolylines):
    """
    Moves all polylines in the model space to the origin by finding the smallest
    x and y coordinates across all vertices and offsetting all points accordingly.
    
    :param lwpolylines: List of polylines where each polyline is a dictionary.
    :return: Updated list of polylines with adjusted coordinates.
    """
    # Initialize global minimum x and y
    global_min_x = float('inf')
    global_min_y = float('inf')
    
    # Find global minimum x and y
    for polyline in lwpolylines:
        for point in polyline["points"]:
            global_min_x = min(global_min_x, point[0])
            global_min_y = min(global_min_y, point[1])
    
    print(f"Global minimum x: {global_min_x}, y: {global_min_y}")
    
    # Offset all points
    for polyline in lwpolylines:
        updated_points = []
        for point in polyline["points"]:
            # Subtract global minimum x and y
            updated_x = point[0] - global_min_x
            updated_y = point[1] - global_min_y
            updated_points.append((updated_x, updated_y))
        
        # Update the polyline's points
        polyline["points"] = updated_points
    
    return lwpolylines

moved_polylines = move_polylines_to_origin(lwpolylines)

# Print updated polylines
for idx, polyline in enumerate(moved_polylines, start=1):
    print(f"LWPOLYLINE {idx}:")
    print(f"  Points: {polyline['points']}")
# Out:
# Global minimum x: 401.1342502864318, y: 345.3502248253358
# LWPOLYLINE 1:
#   Points: [(131991.45661616974, 265175.92384124896), (129661.65391158707, 265175.92384124896), (129661.65391158707, 264041.92384124896), (131991.45661616974, 264041.92384124896)]
# LWPOLYLINE 2:
#   Points: [(132001.44291151754, 265175.92384124896), (134331.24561609977, 265175.92384124896), (134331.24561609956, 264041.92384124896), (132001.44291151717, 264041.92384124896)]
# LWPOLYLINE 3:
#   Points: [(137060.50013458336, 265175.92384124896), (134730.69743000137, 265175.92384124896), (134730.69743000105, 264041.92384124896), (137060.50013458286, 264041.92384124896)]
# LWPOLYLINE 4:
#   Points: [(137070.48642993186, 265175.92384124896), (139400.28913451426, 265175.92384124896), (139400.28913451426, 264041.92384124896), (137070.48642993157, 264041.92384124896)]
    if not isinstance(lwpolylines, list) or not all(isinstance(polyline, dict) and "points" in polyline for polyline in lwpolylines):
        raise ValueError("Input must be a list of dictionaries with a 'points' key.")

    if not lwpolylines:
        return lwpolylines  # Return empty list if input is empty

    # Find the maximum y value across all points
    max_y = float('-inf')
    for polyline in lwpolylines:
        for point in polyline["points"]:
            max_y = max(max_y, point[1])

    print(f"Maximum y value: {max_y}")

    # Mirror points across x-axis and make y positive
    for polyline in lwpolylines:
        updated_points = [
            (point[0], abs(point[1] - max_y)) for point in polyline["points"]
        ]
        polyline["points"] = updated_points

    return lwpolylines


flipped_polylines = mirror_points_across_x_axis(moved_polylines)
# Out:
# Maximum y value: 286887.9238412495

# %%
import matplotlib.pyplot as plt

def plot_polylines(lwpolylines):
    """
    Plots the given polylines in a 2D space.
    
    :param lwpolylines: List of polylines where each polyline is a dictionary
                        with a "points" key (list of (x, y) tuples).
    """
    plt.figure(figsize=(12, 6))  # Create a new figure

    for idx, polyline in enumerate(lwpolylines, start=1):
        # Extract points from the polyline
        points = polyline["points"]
        x_coords, y_coords = zip(*points)  # Separate x and y coordinates
        
        # Close the polyline if it's closed
        if polyline["is_closed"]:
            x_coords = x_coords + (x_coords[0],)  # Add the first x coordinate at the end
            y_coords = y_coords + (y_coords[0],)  # Add the first y coordinate at the end
        
        # Plot the polyline
        plt.plot(x_coords, y_coords, marker="o",markersize="0.002", label=f"Polyline {idx}")

    # Add labels, title, and grid
    plt.xlabel("X Coordinate")
    plt.ylabel("Y Coordinate")
    plt.title("Plot of Polylines")
    plt.grid(True)
    plt.axis("equal")  # Equal scaling for both axes

    # Adjust legend position
    # plt.legend(loc="upper left", bbox_to_anchor=(1.05, 1), borderaxespad=0.)
    
    plt.tight_layout()  # Adjust layout to prevent overlap
    plt.show()


plot_polylines(flipped_polylines)

# %%
def column_index_to_label(index):
    """
    Converts a numeric column index (0-based) to an Excel-style column label.
    For example, 0 -> 'A', 25 -> 'Z', 26 -> 'AA'.
    """
    label = ""
    while index >= 0:
        label = chr(index % 26 + ord('A')) + label
        index = index // 26 - 1
    return label

def find_grid_cell(cellcenter, grid_origin, cell_width, cell_height, grid_rows, grid_columns, orientation):
    """
    Finds the grid cell where the given cellcenter falls, and also returns the adjacent cell
    based on the orientation of the rectangle (horizontal or vertical).
    
    :param cellcenter: Tuple of (x, y) coordinates for the center.
    :param grid_origin: Tuple of (x, y) coordinates for the grid's bottom-left corner.
    :param cell_width: Width of each grid cell.
    :param cell_height: Height of each grid cell.
    :param grid_rows: Total number of rows in the grid.
    :param grid_columns: Total number of columns in the grid.
    :param orientation: The orientation of the rectangle ('Horizontal' or 'Vertical').
    :return: A tuple (current_cell, adjacent_cell) if within the grid, else None.
             For horizontal rectangles, adjacent_cell is below; for vertical, it's to the right.
    """
    x_center, y_center = cellcenter
    x_origin, y_origin = grid_origin

    # Determine column and row indices based on the cellcenter
    col_idx = int((x_center - x_origin) // cell_width)
    row_idx = int((y_center - y_origin) // cell_height)

    # Check if the indices are within the grid bounds
    if 0 <= col_idx < grid_columns and 0 <= row_idx < grid_rows:
        # Get the column label using the column index
        column_label = column_index_to_label(col_idx)
        # Excel-style row is 1-based (e.g., 1 for the first row, 2 for the second row)
        row_label = row_idx + 1  # Row starts at 1, not 0

        # Current cell is the one where the cellcenter falls
        current_cell = f"{column_label}{row_label}"
        
        # Based on the orientation, find the adjacent cell
        if orientation == "Horizontal":
            # For horizontal rectangles, the adjacent cell is directly below
            if row_idx + 1 < grid_rows:
                adjacent_column_label = column_index_to_label(col_idx + 1)
                adjacent_cell = f"{adjacent_column_label}{row_label}"
            else:
                adjacent_cell = None  # No cell below if it's at the edge of the grid
        elif orientation == "Vertical":
            # For vertical rectangles, the adjacent cell is directly to the right
            if col_idx + 1 < grid_columns:
                adjacent_cell = f"{column_label}{row_label + 1}"
            else:
                adjacent_cell = None  # No cell to the right if it's at the edge of the grid
        
        return current_cell, adjacent_cell
    else:
        return None, None  # Cellcenter is out of grid bounds

# %%
# Assuming you already have the function definitions for `check_rectangle_properties`, `column_index_to_label`, and `find_grid_cell`

# Grid parameters
grid_origin = (0, 0)  # Bottom-left corner of the grid (adjust as needed)
cell_width = 1150      # Width of each grid cell
cell_height = 1150      # Height of each grid cell
grid_rows = 1000        # Total number of rows
grid_columns = 1000     # Total number of columns

# Example of how to process the polylines
for idx, polyline in enumerate(lwpolylines, start=1):
    # Assuming check_rectangle_properties returns (orientation, center, average_height, average_width, cellcenter)
    properties = check_rectangle_properties(polyline)
    
    if properties:
        orientation, center, avg_height, avg_width, cellcenter = properties
        # Get the grid cell for the cellcenter
        grid_cell = find_grid_cell(cellcenter, grid_origin, cell_width, cell_height, grid_rows, grid_columns, orientation)
        
        if grid_cell:
            #print(f"LWPOLYLINE {idx}:")
            print(f"  Orientation: {orientation}")
            #print(f"  Center: {center}")
            #print(f"  Average Height: {avg_height}")
            #print(f"  Average Width: {avg_width}")
            #print(f"  Cellcenter: {cellcenter}")
            print(f"  Falls within grid cell: {grid_cell}")
        else:
            print(f"LWPOLYLINE {idx}: Cellcenter {cellcenter} is out of grid bounds.")
    else:
        print(f"LWPOLYLINE {idx}: Not a rectangle")
# Out:
#   Orientation: Horizontal
#   Falls within grid cell: ('DK20', 'DL20')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM20', 'DN20')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO20', 'DP20')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ20', 'DR20')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT20', 'DU20')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV20', 'DW20')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK21', 'DL21')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM21', 'DN21')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO21', 'DP21')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ21', 'DR21')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT21', 'DU21')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV21', 'DW21')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK22', 'DL22')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM22', 'DN22')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO22', 'DP22')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ22', 'DR22')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT22', 'DU22')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV22', 'DW22')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK19', 'DL19')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM19', 'DN19')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO19', 'DP19')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ19', 'DR19')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT19', 'DU19')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV19', 'DW19')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK18', 'DL18')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM18', 'DN18')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO18', 'DP18')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ18', 'DR18')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT18', 'DU18')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV18', 'DW18')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK17', 'DL17')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM17', 'DN17')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO17', 'DP17')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ17', 'DR17')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT17', 'DU17')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV17', 'DW17')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK16', 'DL16')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM16', 'DN16')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO16', 'DP16')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ16', 'DR16')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT16', 'DU16')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV16', 'DW16')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK15', 'DL15')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM15', 'DN15')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO15', 'DP15')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ15', 'DR15')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT15', 'DU15')
#   Orientation: Horizontal
#   Falls within grid cell: ('D

#   Orientation: Horizontal
#   Falls within grid cell: ('DQ114', 'DR114')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT114', 'DU114')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV114', 'DW114')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK113', 'DL113')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM113', 'DN113')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO113', 'DP113')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ113', 'DR113')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT113', 'DU113')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV113', 'DW113')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK112', 'DL112')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM112', 'DN112')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO112', 'DP112')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ112', 'DR112')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT112', 'DU112')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV112', 'DW112')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK111', 'DL111')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM111', 'DN111')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO111', 'DP111')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ111', 'DR111')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT111', 'DU111')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV111', 'DW111')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK110', 'DL110')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM110', 'DN110')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO110', 'DP110')
#   Orientation: Horizontal
#   Falls within grid cell: ('DQ110', 'DR110')
#   Orientation: Horizontal
#   Falls within grid cell: ('DT110', 'DU110')
#   Orientation: Horizontal
#   Falls within grid cell: ('DV110', 'DW110')
#   Orientation: Horizontal
#   Falls within grid cell: ('DK109', 'DL109')
#   Orientation: Horizontal
#   Falls within grid cell: ('DM109', 'DN109')
#   Orientation: Horizontal
#   Falls within grid cell: ('DO109', 'DP109')
#   Orientation: Horizontal
# ...
#   Orientation: Horizontal
#   Falls within grid cell: ('GF238', 'GG238')
#   Orientation: Horizontal
#   Falls within grid cell: ('GG239', 'GH239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GM234', 'GN234')
#   Orientation: Horizontal
#   Falls within grid cell: ('GN234', 'GO234')
#   Orientation: Horizontal
#   Falls within grid cell: ('GL235', 'GM235')
#   Orientation: Horizontal
#   Falls within grid cell: ('GL236', 'GM236')
#   Orientation: Horizontal
#   Falls within grid cell: ('GJ237', 'GK237')
#   Orientation: Horizontal
#   Falls within grid cell: ('GK237', 'GL237')
#   Orientation: Horizontal
#   Falls within grid cell: ('GI238', 'GJ238')
#   Orientation: Horizontal
#   Falls within grid cell: ('GJ239', 'GK239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GG239', 'GH239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GH240', 'GI240')
#   Orientation: Horizontal
#   Falls within grid cell: ('GE234', 'GF234')
#   Orientation: Horizontal
#   Falls within grid cell: ('GO235', 'GP235')
#   Orientation: Horizontal
#   Falls within grid cell: ('GM237', 'GN237')
#   Orientation: Horizontal
#   Falls within grid cell: ('GL238', 'GM238')
#   Orientation: Horizontal
#   Falls within grid cell: ('GJ239', 'GK239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GI241', 'GJ241')
#   Orientation: Horizontal
#   Falls within grid cell: ('GO236', 'GP236')
#   Orientation: Horizontal
#   Falls within grid cell: ('GP237', 'GQ237')
#   Orientation: Horizontal
#   Falls within grid cell: ('GN237', 'GO237')
#   Orientation: Horizontal
#   Falls within grid cell: ('GO238', 'GP238')
#   Orientation: Horizontal
#   Falls within grid cell: ('GL239', 'GM239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GM239', 'GN239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GK240', 'GL240')
#   Orientation: Horizontal
#   Falls within grid cell: ('GL241', 'GM241')
#   Orientation: Horizontal
#   Falls within grid cell: ('GI242', 'GJ242')
#   Orientation: Horizontal
#   Falls within grid cell: ('GJ242', 'GK242')
#   Orientation: Horizontal
#   Falls within grid cell: ('GQ237', 'GR237')
#   Orientation: Horizontal
#   Falls within grid cell: ('GQ238', 'GR238')
#   Orientation: Horizontal
#   Falls within grid cell: ('GO239', 'GP239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GP239', 'GQ239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GN240', 'GO240')
#   Orientation: Horizontal
#   Falls within grid cell: ('GN241', 'GO241')
#   Orientation: Horizontal
#   Falls within grid cell: ('GM242', 'GN242')
#   Orientation: Horizontal
#   Falls within grid cell: ('GK243', 'GL243')
#   Orientation: Horizontal
#   Falls within grid cell: ('GL244', 'GM244')
#   Orientation: Horizontal
#   Falls within grid cell: ('GR239', 'GS239')
#   Orientation: Horizontal
#   Falls within grid cell: ('GQ240', 'GR240')
#   Orientation: Horizontal
#   Falls within grid cell: ('GO242', 'GP242')
#   Orientation: Horizontal
#   Falls within grid cell: ('GN243', 'GO243')
#   Orientation: Horizontal
#   Falls within grid cell: ('GL244', 'GM244')
#   Orientation: Horizontal
#   Falls within grid cell: ('GS240', 'GT240')
#   Orientation: Horizontal
#   Falls within grid cell: ('GS240', 'GT240')
#   Orientation: Horizontal
#   Falls within grid cell: ('GQ241', 'GR241')
#   Orientation: Horizontal
#   Falls within grid cell: ('GR242', 'GS242')
#   Orientation: Horizontal
#   Falls within grid cell: ('GP242', 'GQ242')
#   Orientation: Horizontal
#   Falls within grid cell: ('GQ243', 'GR243')
#   Orientation: Horizontal
#   Falls within grid cell: ('GN244', 'GO244')
#   Orientation: Horizontal
#   Falls within grid cell: ('GO244', 'GP244')
#   Orientation: Horizontal
#   Falls within grid cell: ('GM245', 'GN245')
#   Orientation: Horizontal
#   Falls within grid cell: ('GN246', 'GO246')
#   Orientation: Horizontal
#   Falls within grid cell: ('GT241', 'GU241')
#   Orientation: Horizontal
#   Falls within grid cell: ('GU242', 'GV242')
#   Orientation: Horizontal
#   Falls within grid cell: ('GS242', 'GT242')
#   Orientation: Horizontal
#   Falls within grid cell: ('GS243', 'GT243')
#   Orientation: Horizontal
#   Falls within grid cell: ('GQ244', 'GR244')
#   Orientation: Horizontal
#   Falls within grid cell: ('GR244', 'GS244')
#   Orientation: Horizontal
#   Falls within grid cell: ('GP245', 'GQ245')
#   Orientation: Horizontal
#   Falls within grid cell: ('GQ246', 'GR246')
#   Orientation: Horizontal
#   Falls within grid cell: ('GN247', 'GO247')
#   Orientation: Horizontal
#   Falls within grid cell: ('GO247', 'GP247')
#   Orientation: Horizontal
#   Falls within grid cell: ('GL242', 'GM242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FJ224', 'FK224')
#   Orientation: Horizontal
#   Falls within grid cell: ('FI226', 'FJ226')
#   Orientation: Horizontal
#   Falls within grid cell: ('FG227', 'FH227')
#   Orientation: Horizontal
#   Falls within grid cell: ('FF229', 'FG229')
#   Orientation: Horizontal
#   Falls within grid cell: ('FD230', 'FE230')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK225', 'FL225')
#   Orientation: Horizontal
#   Falls within grid cell: ('FL226', 'FM226')
#   Orientation: Horizontal
#   Falls within grid cell: ('FI227', 'FJ227')
#   Orientation: Horizontal
#   Falls within grid cell: ('FJ227', 'FK227')
#   Orientation: Horizontal
#   Falls within grid cell: ('FH228', 'FI228')
#   Orientation: Horizontal
#   Falls within grid cell: ('FI229', 'FJ229')
#   Orientation: Horizontal
#   Falls within grid cell: ('FF229', 'FG229')
#   Orientation: Horizontal
#   Falls within grid cell: ('FG230', 'FH230')
#   Orientation: Horizontal
#   Falls within grid cell: ('FE231', 'FF231')
#   Orientation: Horizontal
#   Falls within grid cell: ('FF232', 'FG232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FL227', 'FM227')
#   Orientation: Horizontal
#   Falls within grid cell: ('FM227', 'FN227')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK228', 'FL228')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK229', 'FL229')
#   Orientation: Horizontal
#   Falls within grid cell: ('FI229', 'FJ229')
#   Orientation: Horizontal
#   Falls within grid cell: ('FJ230', 'FK230')
#   Orientation: Horizontal
#   Falls within grid cell: ('FI232', 'FJ232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FF232', 'FG232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FG233', 'FH233')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN228', 'FO228')
#   Orientation: Horizontal
#   Falls within grid cell: ('FL229', 'FM229')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK231', 'FL231')
#   Orientation: Horizontal
#   Falls within grid cell: ('FI232', 'FJ232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FH234', 'FI234')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN229', 'FO229')
#   Orientation: Horizontal
#   Falls within grid cell: ('FO230', 'FP230')
#   Orientation: Horizontal
#   Falls within grid cell: ('FM230', 'FN230')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN231', 'FO231')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK232', 'FL232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FL232', 'FM232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FJ233', 'FK233')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK234', 'FL234')
#   Orientation: Horizontal
#   Falls within grid cell: ('FI234', 'FJ234')
#   Orientation: Horizontal
#   Falls within grid cell: ('FI235', 'FJ235')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP230', 'FQ230')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP231', 'FQ231')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN232', 'FO232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FO232', 'FP232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FM233', 'FN233')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN234', 'FO234')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK234', 'FL234')
#   Orientation: Horizontal
#   Falls within grid cell: ('FL235', 'FM235')
#   Orientation: Horizontal
#   Falls within grid cell: ('FJ236', 'FK236')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK237', 'FL237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FH231', 'FI231')
#   Orientation: Horizontal
#   Falls within grid cell: ('FQ232', 'FR232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP233', 'FQ233')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN235', 'FO235')
#   Orientation: Horizontal
#   Falls within grid cell: ('FM236', 'FN236')
#   Orientation: Horizontal
#   Falls within grid cell: ('FK237', 'FL237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FR232', 'FS232')
#   Orientation: Horizontal
#   Falls within grid cell: ('FS233', 'FT233')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP234', 'FQ234')
#   Orientation: Horizontal
#   Falls within grid cell: ('FQ235', 'FR235')
#   Orientation: Horizontal
#   Falls within grid cell: ('FO235', 'FP235')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP236', 'FQ236')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN237', 'FO237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN237', 'FO237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FL238', 'FM238')
#   Orientation: Horizontal
#   Falls within grid cell: ('FM239', 'FN239')
#   Orientation: Horizontal
#   Falls within grid cell: ('FS234', 'FT234')
#   Orientation: Horizontal
#   Falls within grid cell: ('FT235', 'FU235')
#   Orientation: Horizontal
#   Falls within grid cell: ('FR235', 'FS235')
#   Orientation: Horizontal
#   Falls within grid cell: ('FS236', 'FT236')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP237', 'FQ237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FQ237', 'FR237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP239', 'FQ239')
#   Orientation: Horizontal
#   Falls within grid cell: ('FM239', 'FN239')
#   Orientation: Horizontal
#   Falls within grid cell: ('FN240', 'FO240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU235', 'FV235')
#   Orientation: Horizontal
#   Falls within grid cell: ('FS237', 'FT237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FR238', 'FS238')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP240', 'FQ240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FO241', 'FP241')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU236', 'FV236')
#   Orientation: Horizontal
#   Falls within grid cell: ('FV237', 'FW237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FT237', 'FU237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU238', 'FV238')
#   Orientation: Horizontal
#   Falls within grid cell: ('FR239', 'FS239')
#   Orientation: Horizontal
#   Falls within grid cell: ('FS240', 'FT240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FQ240', 'FR240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FR241', 'FS241')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP242', 'FQ242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FP242', 'FQ242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW237', 'FX237')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW238', 'FX238')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU239', 'FV239')
#   Orientation: Horizontal
#   Falls within grid cell: ('FV240', 'FW240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FT240', 'FU240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU241', 'FV241')
#   Orientation: Horizontal
#   Falls within grid cell: ('FR242', 'FS242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FS242', 'FT242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FQ243', 'FR243')
#   Orientation: Horizontal
#   Falls within grid cell: ('FR244', 'FS244')
#   Orientation: Horizontal
#   Falls within grid cell: ('FO238', 'FP238')
#   Orientation: Horizontal
#   Falls within grid cell: ('FX239', 'FY239')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW240', 'FX240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU242', 'FV242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FT243', 'FU243')
#   Orientation: Horizontal
#   Falls within grid cell: ('FR245', 'FS245')
#   Orientation: Horizontal
#   Falls within grid cell: ('FY240', 'FZ240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FZ240', 'GA240')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW241', 'FX241')
#   Orientation: Horizontal
#   Falls within grid cell: ('FX242', 'FY242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FV242', 'FW242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW243', 'FX243')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU244', 'FV244')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU245', 'FV245')
#   Orientation: Horizontal
#   Falls within grid cell: ('FS245', 'FT245')
#   Orientation: Horizontal
#   Falls within grid cell: ('FT246', 'FU246')
#   Orientation: Horizontal
#   Falls within grid cell: ('FZ241', 'GA241')
#   Orientation: Horizontal
#   Falls within grid cell: ('GA242', 'GB242')
#   Orientation: Horizontal
#   Falls within grid cell: ('FY243', 'FZ243')
#   Orientation: Horizontal
#   Falls within grid cell: ('FZ243', 'GA243')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW244', 'FX244')
#   Orientation: Horizontal
#   Falls within grid cell: ('FX245', 'FY245')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW246', 'FX246')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU247', 'FV247')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU247', 'FV247')
#   Orientation: Horizontal
#   Falls within grid cell: ('GB243', 'GC243')
#   Orientation: Horizontal
#   Falls within grid cell: ('FZ244', 'GA244')
#   Orientation: Horizontal
#   Falls within grid cell: ('FY245', 'FZ245')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW247', 'FX247')
#   Orientation: Horizontal
#   Falls within grid cell: ('FV248', 'FW248')
#   Orientation: Horizontal
#   Falls within grid cell: ('GB243', 'GC243')
#   Orientation: Horizontal
#   Falls within grid cell: ('GA245', 'GB245')
#   Orientation: Horizontal
#   Falls within grid cell: ('FZ246', 'GA246')
#   Orientation: Horizontal
#   Falls within grid cell: ('FX248', 'FY248')
#   Orientation: Horizontal
#   Falls within grid cell: ('FW249', 'FX249')
#   Orientation: Horizontal
#   Falls within grid cell: ('FV245', 'FW245')
#   Orientation: Vertical
#   Falls within grid cell: ('EZ218', 'EZ219')
#   Orientation: Vertical
#   Falls within grid cell: ('EY220', 'EY221')
#   Orientation: Vertical
#   Falls within grid cell: ('EX221', 'EX222')
#   Orientation: Vertical
#   Falls within grid cell: ('EW223', 'EW224')
#   Orientation: Vertical
#   Falls within grid cell: ('EV225', 'EV226')
#   Orientation: Vertical
#   Falls within grid cell: ('FA219', 'FA220')
#   Orientation: Vertical
#   Falls within grid cell: ('FB219', 'FB220')
#   Orientation: Vertical
#   Falls within grid cell: ('EZ220', 'EZ221')
#   Orientation: Vertical
#   Falls within grid cell: ('FA221', 'FA222')
#   Orientation: Vertical
#   Falls within grid cell: ('EY222', 'EY223')
#   Orientation: Vertical
#   Falls within grid cell: ('EZ223', 'EZ224')
#   Orientation: Vertical
#   Falls within grid cell: ('EX224', 'EX225')
#   Orientation: Vertical
#   Falls within grid cell: ('EX224', 'EX225')
#   Orientation: Vertical
#   Falls within grid cell: ('EV225', 'EV226')
#   Orientation: Vertical
#   Falls within grid cell: ('EW226', 'EW227')
#   Orientation: Vertical
#   Falls within grid cell: ('FC220', 'FC221')
#   Orientation: Vertical
#   Falls within grid cell: ('FD221', 'FD222')
#   Orientation: Vertical
#   Falls within grid cell: ('FB222', 'FB223')
#   Orientation: Vertical
#   Falls within grid cell: ('FB222', 'FB223')
#   Orientation: Vertical
#   Falls within grid cell: ('EZ223', 'EZ224')
#   Orientation: Vertical
#   Falls within grid cell: ('FA224', 'FA225')
#   Orientation: Vertical
#   Falls within grid cell: ('EZ226', 'EZ227')
#   Orientation: Vertical
#   Falls within grid cell: ('EX227', 'EX228')
#   Orientation: Vertical
#   Falls within grid cell: ('EY227', 'EY228')
#   Orientation: Vertical
#   Falls within grid cell: ('EY225', 'EY226')
#   Orientation: Vertical
#   Falls within grid cell: ('ED183', 'ED184')
#   Orientation: Horizontal
#   Falls within grid cell: ('FU221', 'FV221')
#   Orientation: Horizontal
#   Falls within grid cell: ('FX221', 'FY221')

# %%
# Specify the output file path
output_file = "grid_cells_output.txt"

# Open the file in write mode
with open(output_file, "w") as file:
    for idx, polyline in enumerate(lwpolylines, start=1):
        # Assuming check_rectangle_properties returns (orientation, center, average_height, average_width, cellcenter)
        properties = check_rectangle_properties(polyline)
        
        if properties:
            orientation, center, avg_height, avg_width, cellcenter = properties
            # Get the grid cell for the cellcenter
            grid_cell = find_grid_cell(cellcenter, grid_origin, cell_width, cell_height, grid_rows, grid_columns, orientation)
            
            if grid_cell:
                # Write the grid cell to the file
                file.write(f"{grid_cell}\n")
            else:
                file.write(f"LWPOLYLINE {idx}: Cellcenter {cellcenter} is out of grid bounds.\n")
        else:
            file.write(f"LWPOLYLINE {idx}: Not a rectangle\n")
